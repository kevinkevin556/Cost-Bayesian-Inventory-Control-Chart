# %%
import sys
import pathlib
sys.path.append(str(pathlib.Path.cwd().parents[1]))

from control_chart.cost_bayesian import CostBayesianControlChart
from meter import Meter
from random_demand import stepwise_increasing

p = 7
c = 5
r = 4
meter = Meter(p, c, r)

for i in range(60):
    demand = stepwise_increasing(mu={0:1000, 13:1020, 26:1040, 39:1060}, sigma=10, n=52, random_state=i)
    control_chart = CostBayesianControlChart(mu0=1000, sigma=10, p=p, c=c, r=r, T=13, N=6, rule=3, p_=None)
    purchased = []
    for t, d in enumerate(demand):
        purchased.append(control_chart.purchase())
        control_chart.test(d, t)
    print(f"{i:>2} " , end="")
    results = meter(demand, purchased, verbose=True)
print("----------------------------------------------------------------------")
stats = meter.calculate_statistics()
# Out:
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in log
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in scalar divide
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# 14 Out of control 1024.0015720836723 New (mu, sigma) = (1010.6025307099295, 10)
# 15 Out of control 1029.7873798410574 New (mu, sigma) = (1029.7873798410574, 10)
# 29 Out of control 1062.4089319920147 New (mu, sigma) = (1034.2717712212577, 10)
# 30 Out of control 1058.6755799014998 New (mu, sigma) = (1058.6755799014998, 10)
# 31 Out of control 1030.2272212012358 New (mu, sigma) = (1030.2272212012358, 10)
# 40 Out of control 1064.0015720836723 New (mu, sigma) = (1050.699639129976, 10)
# 41 Out of control 1069.7873798410574 New (mu, sigma) = (1069.7873798410574, 10)
#  0 n_stockout:        422.4303 | n_holding:        238.0167 | stockout_cost:        844.8606 | holding_cost:        238.0167 | total_cost:       1082.8773 | service_level:          0.4038
# 14 Out of control 1013.8824358634993 New (mu, sigma) = (1002.0804867103241, 10)
# 15 Out of control 1014.7182824773654 New (mu, sigma) = (1014.7182824773654, 10)
# 27 Out of control 1033.8824358634993 New (mu, sigma) = (1022.1969273897803, 10)
# 28 Out of control 1034.7182824773654 New (mu, sigma) = (1034.7182824773654, 10)
# 40 Out of control 1053.8824358634993 New (mu, sigma) = (1042.1969273897803, 10)
# 41 Out of control 1054.7182824773654 New (mu, sigma) = (1054.7182824773654, 10)
#  1 n_stockout:        353.5915 | n_holding:        300.1400 | stockout_cost:        707.1831 | holding_cost:        300.1400 | total_cost:       1007.3231 | service_level:          0.5192
# 17 Out of control 1002.0656441480513 New (mu, sigma) = (1002.1162869373804, 10)
# 18 Out of control 1011.582526343438 New (mu, sigma) = (1011.582526343438, 10)
# 25 Out of control 1020.415393929984 New (mu, sigma) = (1020.2511927816021, 10)
# 30 Out of control 1022.0656441480513 New (mu, sigma) = (1034.47522890582, 10)
# 31 Out of control 1031.5825263434378 New (mu, sigma) = (1031.5825263434378, 10)
# 38 Out of control 1040.415393929984 New (mu, sigma) = (1040.251192781602, 10)
# 43 Out of control 1042.0656441480514 New (mu, sigma) = (1054.47522890582, 10)
# 44 Out of control 1051.5825263434378 New (mu, sigma) = (1051.5825263434378, 10)
# 51 Out of control 1060.415393929984 New (mu, sigma) = (1060.251192781602, 10)
#  2 n_stockout:        363.5077 | n_holding:        221.4295 | stockout_cost:        727.0154 | holding_cost:        221.4295 | total_cost:        948.4449 | service_level:          0.5000
# 14 Out of control 1024.36509850512 New (mu, sigma) = (1003.5149543616743, 10)
# 15 Out of control 1020.96497468072 New (mu, sigma) = (1020.96497468072, 10)
# 27 Out of control 1044.36509850512 New (mu, sigma) = (1022.4589964587476, 10)
# 28 Out of control 1040.9649746807202 New (mu, sigma) = (1040.9649746807202, 10)
# 40 Out of control 1064.36509850512 New (mu, sigma) = (1042.4589964587476, 10)
# 41 Out of control 1060.9649746807202 New (mu, sigma) = (1060.9649746807202, 10)
#  3 n_stockout:        242.6172 | n_holding:        365.9457 | stockout_cost:        485.2344 | holding_cost:        365.9457 | total_cost:        851.1801 | service_level:          0.6346
# 15 Out of control 1010.0409106889314 New (mu, sigma) = (1002.4320780846149, 10)
# 17 Out of control 1015.8169847997309 New (mu, sigma) = (1021.3764849413219, 10)
# 30 Out of control 1035.8169847997308 New (mu, sigma) = (1026.4128621739305, 10)
# 40 Out of control 1064.9995133323782 New (mu, sigma) = (1043.0573327689522, 10)
# 41 Out of control 1050.0409106889313 New (mu, sigma) = (1050.0409106889313, 10)
#  4 n_stockout:        345.4531 | n_holding:        166.3160 | stockout_cost:        690.9062 | holding_cost:        166.3160 | total_cost:        857.2221 | service_level:          0.3846
# 16 Out of control 1017.4790787039692 New (mu, sigma) = (1006.3944458109952, 10)
# 17 Out of control 1021.0960984157819 New (mu, sigma) = (1021.0960984157819, 10)
# 29 Out of control 1037.4790787039692 New (mu, sigma) = (1027.059926370598, 10)
# 30 Out of control 1041.0960984157819 New (mu, sigma) = (1041.0960984157819, 10)
# 42 Out of control 1057.4790787039692 New (mu, sigma) = (1047.059926370598, 10)
# 43 Out of control 1061.0960984157819 New (mu, sigma) = (1061.0960984157819, 10)
#  5 n_stockout:        340.9545 | n_holding:        297.2613 | stockout_cost:        681.9090 | holding_cost:        297.2613 | total_cost:        979.1703 | service_level:          0.5962
# 16 Out of control 1011.0090820345287 New (mu, sigma) = (1005.6576226602742, 10)
# 17 Out of control 995.1321934837214 New (mu, sigma) = (995.1321934837214, 10)
# 19 Out of control 1031.2706372597183 New (mu, sigma) = (1030.2015762360386, 10)
# 20 Out of control 1004.8590677136979 New (mu, sigma) = (1004.8590677136979, 10)
# 22 Out of control 1015.7010639699365 New (mu, sigma) = (1026.0469873996567, 10)
# 23 Out of control 1046.3128055726381 New (mu, sigma) = (1046.3128055726381, 10)
# 46 Out of control 1044.8590677136979 New (mu, sigma) = (1045.1840610975778, 10)
# 48 Out of control 1055.7010639699365 New (mu, sigma) = (1066.0469873996567, 10)
#  6 n_stockout:        367.1761 | n_holding:        371.4662 | stockout_cost:        734.3522 | holding_cost:        371.4662 | total_cost:       1105.8184 | service_level:          0.4808
# 14 Out of control 1015.3406262945916 New (mu, sigma) = (1003.7823464172591, 10)
# 15 Out of control 1020.3282016367858 New (mu, sigma) = (1020.3282016367858, 10)
# 27 Out of control 1035.3406262945916 New (mu, sigma) = (1023.6800926074585, 10)
# 28 Out of control 1040.328201636786 New (mu, sigma) = (1040.328201636786, 10)
# 40 Out of control 1055.3406262945916 New (mu, sigma) = (1043.6800926074586, 10)
# 41 Out of control 1060.328201636786 New (mu, sigma) = (1060.328201636786, 10)
#  7 n_stockout:        209.3966 | n_holding:        257.7189 | stockout_cost:        418.7932 | holding_cost:        257.7189 | total_cost:        676.5121 | service_level:          0.5769
# 8 Out of control 1007.948276393484 New (mu, sigma) = (1002.9885893669515, 10)
# 15 Out of control 1000.5302969097745 New (mu, sigma) = (1008.3164969998882, 10)
# 19 Out of control 1037.2783616857992 New (mu, sigma) = (1021.1370734137059, 10)
# 20 Out of control 1042.0455628455613 New (mu, sigma) = (1042.0455628455613, 10)
# 41 Out of control 1040.5302969097745 New (mu, sigma) = (1039.9486365374187, 10)
# 45 Out of control 1077.2783616857992 New (mu, sigma) = (1061.1370734137058, 10)
# 46 Out of control 1082.0455628455613 New (mu, sigma) = (1082.0455628455613, 10)
#  8 n_stockout:        382.2539 | n_holding:        504.6411 | stockout_cost:        764.5079 | holding_cost:        504.6411 | total_cost:       1269.1490 | service_level:          0.5192
# 25 Out of control 1022.9668221771141 New (mu, sigma) = (1008.0761369254374, 10)
# 26 Out of control 1040.011085547122 New (mu, sigma) = (1040.011085547122, 10)
# 51 Out of control 1062.966822177114 New (mu, sigma) = (1048.39873898057, 10)
#  9 n_stockout:        415.7429 | n_holding:        188.1153 | stockout_cost:        831.4859 | holding_cost:        188.1153 | total_cost:       1019.6011 | service_level:          0.4038
# 14 Out of control 1027.1527897439842 New (mu, sigma) = (1004.8772976354568, 10)
# 15 Out of control 1004.5459970788874 New (mu, sigma) = (1004.5459970788874, 10)
# 16 Out of control 1019.9161615007148 New (mu, sigma) = (1019.9161615007148, 10)
# 27 Out of control 1047.1527897439842 New (mu, sigma) = (1026.2026046515425, 10)
# 28 Out of control 1024.5459970788872 New (mu, sigma) = (1024.5459970788872, 10)
# 29 Out of control 1039.9161615007147 New (mu, sigma) = (1039.9161615007147, 10)
# 40 Out of control 1067.1527897439842 New (mu, sigma) = (1046.2026046515425, 10)
# 41 Out of control 1044.5459970788872 New (mu, sigma) = (1044.5459970788872, 10)
# 42 Out of control 1059.9161615007147 New (mu, sigma) = (1059.9161615007147, 10)
# 10 n_stockout:        240.3037 | n_holding:        201.8402 | stockout_cost:        480.6074 | holding_cost:        201.8402 | total_cost:        682.4476 | service_level:          0.5577
# 14 Out of control 1017.1392700318371 New (mu, sigma) = (1001.2819293292789, 10)
# 15 Out of control 1015.1543486777886 New (mu, sigma) = (1015.1543486777886, 10)
# 27 Out of control 1037.139270031837 New (mu, sigma) = (1020.7867311513754, 10)
# 28 Out of control 1035.1543486777884 New (mu, sigma) = (1035.1543486777884, 10)
# 40 Out of control 1057.139270031837 New (mu, sigma) = (1040.7867311513753, 10)
# 41 Out of control 1055.1543486777884 New (mu, sigma) = (1055.1543486777884, 10)
# 11 n_stockout:        251.8992 | n_holding:        275.6001 | stockout_cost:        503.7983 | holding_cost:        275.6001 | total_cost:        779.3984 | service_level:          0.5577
# 16 Out of control 1002.9926436596166 New (mu, sigma) = (1004.0031036703979, 10)
# 23 Out of control 1014.0217708059365 New (mu, sigma) = (1020.8147649981811, 10)
# 24 Out of control 1024.7245699353575 New (mu, sigma) = (1024.7245699353575, 10)
# 36 Out of control 1034.0217708059365 New (mu, sigma) = (1038.3329628595318, 10)
# 37 Out of control 1044.7245699353575 New (mu, sigma) = (1044.7245699353575, 10)
# 49 Out of control 1054.0217708059365 New (mu, sigma) = (1058.3329628595318, 10)
# 50 Out of control 1064.7245699353575 New (mu, sigma) = (1064.7245699353575, 10)
# 12 n_stockout:        423.8935 | n_holding:        112.6079 | stockout_cost:        847.7870 | holding_cost:        112.6079 | total_cost:        960.3949 | service_level:          0.2885
# 16 Out of control 1024.518123387458 New (mu, sigma) = (1007.0186877921052, 10)
# 17 Out of control 1033.45101708451 New (mu, sigma) = (1033.45101708451, 10)
# 41 Out of control 1059.5549692166194 New (mu, sigma) = (1037.9871893716363, 10)
# 42 Out of control 1064.518123387458 New (mu, sigma) = (1064.518123387458, 10)
# 13 n_stockout:        325.5551 | n_holding:        278.7033 | stockout_cost:        651.1101 | holding_cost:        278.7033 | total_cost:        929.8134 | service_level:          0.4423
# 14 Out of control 1020.7918602460882 New (mu, sigma) = (1002.3280708443531, 10)
# 15 Out of control 1021.7397652845617 New (mu, sigma) = (1021.7397652845617, 10)
# 27 Out of control 1040.7918602460882 New (mu, sigma) = (1021.4063371685097, 10)
# 28 Out of control 1041.7397652845616 New (mu, sigma) = (1041.7397652845616, 10)
# 29 Out of control 1039.2766343383382 New (mu, sigma) = (1039.2766343383382, 10)
# 40 Out of control 1060.7918602460882 New (mu, sigma) = (1041.5999465167072, 10)
# 41 Out of control 1061.7397652845616 New (mu, sigma) = (1061.7397652845616, 10)
# 14 n_stockout:        222.6045 | n_holding:        389.5113 | stockout_cost:        445.2089 | holding_cost:        389.5113 | total_cost:        834.7203 | service_level:          0.7308
# 18 Out of control 1002.3639474319579 New (mu, sigma) = (1002.9284300277233, 10)
# 19 Out of control 1009.0413795605529 New (mu, sigma) = (1009.0413795605529, 10)
# 27 Out of control 1043.392847060462 New (mu, sigma) = (1023.7554900207922, 10)
# 28 Out of control 1038.4409146611729 New (mu, sigma) = (1038.4409146611729, 10)
# 29 Out of control 1034.9821032670225 New (mu, sigma) = (1034.9821032670225, 10)
# 41 Out of control 1058.4409146611729 New (mu, sigma) = (1041.8538208947734, 10)
# 42 Out of control 1054.9821032670225 New (mu, sigma) = (1054.9821032670225, 10)
# 15 n_stockout:        276.2974 | n_holding:        205.2977 | stockout_cost:        552.5948 | holding_cost:        205.2977 | total_cost:        757.8925 | service_level:          0.5192
# 25 Out of control 1011.6059568677374 New (mu, sigma) = (1005.4256785789416, 10)
# 26 Out of control 1041.2794872113393 New (mu, sigma) = (1041.2794872113393, 10)
# 16 n_stockout:        306.1715 | n_holding:        245.4272 | stockout_cost:        612.3429 | holding_cost:        245.4272 | total_cost:        857.7702 | service_level:          0.4615
# 17 Out of control 1030.371904682279 New (mu, sigma) = (1008.3803152573855, 10)
# 18 Out of control 1038.866389297816 New (mu, sigma) = (1038.866389297816, 10)
# 43 Out of control 1070.371904682279 New (mu, sigma) = (1040.7305658544499, 10)
# 44 Out of control 1078.866389297816 New (mu, sigma) = (1078.866389297816, 10)
# 17 n_stockout:        367.1836 | n_holding:        449.7360 | stockout_cost:        734.3671 | holding_cost:        449.7360 | total_cost:       1184.1031 | service_level:          0.5769
# 15 Out of control 1018.6510785339173 New (mu, sigma) = (1008.570914986715, 10)
# 16 Out of control 1021.6051798245487 New (mu, sigma) = (1021.6051798245487, 10)
# 28 Out of control 1038.6510785339174 New (mu, sigma) = (1029.5151727847308, 10)
# 29 Out of control 1041.6051798245487 New (mu, sigma) = (1041.6051798245487, 10)
# 41 Out of control 1058.6510785339174 New (mu, sigma) = (1049.5151727847308, 10)
# 42 Out of control 1061.6051798245487 New (mu, sigma) = (1061.6051798245487, 10)
# 18 n_stockout:        270.4677 | n_holding:        111.8691 | stockout_cost:        540.9354 | holding_cost:        111.8691 | total_cost:        652.8044 | service_level:          0.4808
# 20 Out of control 1025.8075341108588 New (mu, sigma) = (1006.114919133626, 10)
# 21 Out of control 1022.5241373645007 New (mu, sigma) = (1022.5241373645007, 10)
# 34 Out of control 1042.5241373645008 New (mu, sigma) = (1031.672012754527, 10)
# 35 Out of control 1025.3745404702333 New (mu, sigma) = (1025.3745404702333, 10)
# 40 Out of control 1056.595349910216 New (mu, sigma) = (1045.1931469027732, 10)
# 41 Out of control 1054.2225145801947 New (mu, sigma) = (1054.2225145801947, 10)
# 19 n_stockout:        375.7098 | n_holding:        197.6351 | stockout_cost:        751.4197 | holding_cost:        197.6351 | total_cost:        949.0547 | service_level:          0.4231
# 15 Out of control 1023.5753651588528 New (mu, sigma) = (1003.6967025321862, 10)
# 16 Out of control 996.5673809435979 New (mu, sigma) = (996.5673809435979, 10)
# 19 Out of control 1029.3946934985609 New (mu, sigma) = (1021.3811101731422, 10)
# 28 Out of control 1043.575365158853 New (mu, sigma) = (1027.1181758385057, 10)
# 29 Out of control 1016.5673809435979 New (mu, sigma) = (1016.5673809435979, 10)
# 32 Out of control 1049.3946934985609 New (mu, sigma) = (1041.3811101731424, 10)
# 41 Out of control 1063.575365158853 New (mu, sigma) = (1047.1181758385055, 10)
# 42 Out of control 1036.567380943598 New (mu, sigma) = (1036.567380943598, 10)
# 45 Out of control 1069.3946934985609 New (mu, sigma) = (1061.3811101731424, 10)
# 20 n_stockout:        372.2573 | n_holding:        257.3244 | stockout_cost:        744.5146 | holding_cost:        257.3244 | total_cost:       1001.8390 | service_level:          0.5769
# 16 Out of control 1007.4326070593502 New (mu, sigma) = (1005.4851123174262, 10)
# 17 Out of control 1027.4538768149725 New (mu, sigma) = (1027.4538768149725, 10)
# 39 Out of control 1059.4803575049448 New (mu, sigma) = (1034.9937901512587, 10)
# 40 Out of control 1058.8880394964558 New (mu, sigma) = (1058.8880394964558, 10)
# 21 n_stockout:        348.1025 | n_holding:        236.2016 | stockout_cost:        696.2051 | holding_cost:        236.2016 | total_cost:        932.4067 | service_level:          0.4231
# 16 Out of control 1017.6067483180243 New (mu, sigma) = (1003.1452587958032, 10)
# 17 Out of control 1015.0887086376157 New (mu, sigma) = (1015.0887086376157, 10)
# 29 Out of control 1037.6067483180243 New (mu, sigma) = (1025.4590859589835, 10)
# 30 Out of control 1035.0887086376158 New (mu, sigma) = (1035.0887086376158, 10)
# 42 Out of control 1057.6067483180243 New (mu, sigma) = (1045.4590859589835, 10)
# 43 Out of control 1055.0887086376158 New (mu, sigma) = (1055.0887086376158, 10)
# 22 n_stockout:        311.5243 | n_holding:        170.0136 | stockout_cost:        623.0486 | holding_cost:        170.0136 | total_cost:        793.0622 | service_level:          0.4038
# 15 Out of control 1012.2238058680819 New (mu, sigma) = (1003.7622769642439, 10)
# 17 Out of control 1027.0167179464752 New (mu, sigma) = (1028.2515280857124, 10)
# 18 Out of control 1009.4891843609288 New (mu, sigma) = (1009.4891843609288, 10)
# 27 Out of control 1040.2581308106628 New (mu, sigma) = (1024.7587297539094, 10)
# 28 Out of control 1032.2238058680819 New (mu, sigma) = (1032.2238058680819, 10)
# 40 Out of control 1060.2581308106628 New (mu, sigma) = (1044.0684006931288, 10)
# 41 Out of control 1052.2238058680819 New (mu, sigma) = (1052.2238058680819, 10)
# 42 Out of control 1069.4863382249493 New (mu, sigma) = (1069.4863382249493, 10)
# 23 n_stockout:        362.7543 | n_holding:        276.8465 | stockout_cost:        725.5087 | holding_cost:        276.8465 | total_cost:       1002.3551 | service_level:          0.4615
# 14 Out of control 1012.2996654799515 New (mu, sigma) = (1002.856435195513, 10)
# 25 Out of control 1029.6153839867832 New (mu, sigma) = (1019.2420866836187, 10)
# 26 Out of control 1053.2921217264918 New (mu, sigma) = (1053.2921217264918, 10)
# 24 n_stockout:        314.7397 | n_holding:        372.6649 | stockout_cost:        629.4795 | holding_cost:        372.6649 | total_cost:       1002.1443 | service_level:          0.5192
# 15 Out of control 1011.6041515103482 New (mu, sigma) = (1003.8087587118599, 10)
# 16 Out of control 1014.0881848209935 New (mu, sigma) = (1014.0881848209935, 10)
# 27 Out of control 1050.26890303163 New (mu, sigma) = (1024.6447288745253, 10)
# 28 Out of control 1031.6041515103482 New (mu, sigma) = (1031.6041515103482, 10)
# 40 Out of control 1070.26890303163 New (mu, sigma) = (1043.765016870064, 10)
# 41 Out of control 1051.6041515103482 New (mu, sigma) = (1051.6041515103482, 10)
# 25 n_stockout:        403.9039 | n_holding:        203.2245 | stockout_cost:        807.8077 | holding_cost:        203.2245 | total_cost:       1011.0322 | service_level:          0.4808
# 17 Out of control 1017.7113787895368 New (mu, sigma) = (1003.8424398147033, 10)
# 18 Out of control 1022.7175082598039 New (mu, sigma) = (1022.7175082598039, 10)
# 30 Out of control 1037.7113787895369 New (mu, sigma) = (1026.035677101834, 10)
# 32 Out of control 1039.7093104955213 New (mu, sigma) = (1041.2134093776626, 10)
# 43 Out of control 1057.7113787895369 New (mu, sigma) = (1046.6108013387714, 10)
# 44 Out of control 1062.717508259804 New (mu, sigma) = (1062.717508259804, 10)
# 26 n_stockout:        283.1312 | n_holding:        314.0316 | stockout_cost:        566.2623 | holding_cost:        314.0316 | total_cost:        880.2939 | service_level:          0.5385
# 14 Out of control 1016.9644662269385 New (mu, sigma) = (1006.4166418655747, 10)
# 16 Out of control 1023.9599854914377 New (mu, sigma) = (1025.0753710550662, 10)
# 29 Out of control 1043.9599854914377 New (mu, sigma) = (1029.725315969566, 10)
# 40 Out of control 1056.9644662269384 New (mu, sigma) = (1046.9343968631113, 10)
# 41 Out of control 1066.1907566186944 New (mu, sigma) = (1066.1907566186944, 10)
# 27 n_stockout:        317.1650 | n_holding:        170.0603 | stockout_cost:        634.3300 | holding_cost:        170.0603 | total_cost:        804.3903 | service_level:          0.4808
# 15 Out of control 1017.3572003817623 New (mu, sigma) = (1003.8148944476496, 10)
# 16 Out of control 1010.3216507062622 New (mu, sigma) = (1010.3216507062622, 10)
# 27 Out of control 1056.6912005100796 New (mu, sigma) = (1023.1679759458024, 10)
# 28 Out of control 1037.3572003817621 New (mu, sigma) = (1037.3572003817621, 10)
# 29 Out of control 1030.3216507062623 New (mu, sigma) = (1030.3216507062623, 10)
# 40 Out of control 1076.6912005100796 New (mu, sigma) = (1043.1679759458025, 10)
# 41 Out of control 1057.3572003817621 New (mu, sigma) = (1057.3572003817621, 10)
# 42 Out of control 1050.3216507062623 New (mu, sigma) = (1050.3216507062623, 10)
# 28 n_stockout:        391.7275 | n_holding:        190.4358 | stockout_cost:        783.4551 | holding_cost:        190.4358 | total_cost:        973.8909 | service_level:          0.4038
# 16 Out of control 998.5824450427 New (mu, sigma) = (1005.0727552582406, 10)
# 17 Out of control 1027.1905689020487 New (mu, sigma) = (1027.1905689020487, 10)
# 29 Out of control 1018.5824450427 New (mu, sigma) = (1026.534873226801, 10)
# 30 Out of control 1047.1905689020487 New (mu, sigma) = (1047.1905689020487, 10)
# 42 Out of control 1038.5824450426999 New (mu, sigma) = (1046.534873226801, 10)
# 43 Out of control 1067.1905689020487 New (mu, sigma) = (1067.1905689020487, 10)
# 29 n_stockout:        247.2399 | n_holding:        397.0226 | stockout_cost:        494.4799 | holding_cost:        397.0226 | total_cost:        891.5025 | service_level:          0.6346
# 15 Out of control 1010.2928906199114 New (mu, sigma) = (1003.1676183213906, 10)
# 16 Out of control 1024.7055961588642 New (mu, sigma) = (1024.7055961588642, 10)
# 28 Out of control 1030.2928906199113 New (mu, sigma) = (1024.4204066245711, 10)
# 34 Out of control 1041.342965931276 New (mu, sigma) = (1041.111809363148, 10)
# 41 Out of control 1050.2928906199113 New (mu, sigma) = (1047.2970884964043, 10)
# 30 n_stockout:        360.4245 | n_holding:        240.3116 | stockout_cost:        720.8490 | holding_cost:        240.3116 | total_cost:        961.1606 | service_level:          0.4423
# 21 Out of control 1012.9439968915392 New (mu, sigma) = (1005.8824171814056, 10)
# 22 Out of control 1019.1395796643105 New (mu, sigma) = (1019.1395796643105, 10)
# 34 Out of control 1032.9439968915392 New (mu, sigma) = (1032.583817691632, 10)
# 35 Out of control 1039.1395796643105 New (mu, sigma) = (1039.1395796643105, 10)
# 47 Out of control 1052.9439968915392 New (mu, sigma) = (1052.583817691632, 10)
# 48 Out of control 1059.1395796643105 New (mu, sigma) = (1059.1395796643105, 10)
# 31 n_stockout:        404.6277 | n_holding:        155.8430 | stockout_cost:        809.2554 | holding_cost:        155.8430 | total_cost:        965.0985 | service_level:          0.4038
# 15 Out of control 1025.8092283071715 New (mu, sigma) = (1009.4357952985999, 10)
# 16 Out of control 1020.7028444085745 New (mu, sigma) = (1020.7028444085745, 10)
# 28 Out of control 1045.8092283071715 New (mu, sigma) = (1031.5093801865194, 10)
# 29 Out of control 1040.7028444085745 New (mu, sigma) = (1040.7028444085745, 10)
# 41 Out of control 1065.8092283071715 New (mu, sigma) = (1051.5093801865191, 10)
# 42 Out of control 1060.7028444085745 New (mu, sigma) = (1060.7028444085745, 10)
# 32 n_stockout:        410.8396 | n_holding:        135.2046 | stockout_cost:        821.6792 | holding_cost:        135.2046 | total_cost:        956.8838 | service_level:          0.2692
# 21 Out of control 1019.0321584169009 New (mu, sigma) = (1005.9513609101791, 10)
# 22 Out of control 1024.2220166048146 New (mu, sigma) = (1024.2220166048146, 10)
# 34 Out of control 1039.0321584169008 New (mu, sigma) = (1032.4129589090019, 10)
# 35 Out of control 1044.2220166048146 New (mu, sigma) = (1044.2220166048146, 10)
# 47 Out of control 1059.0321584169008 New (mu, sigma) = (1052.4129589090019, 10)
# 48 Out of control 1064.2220166048146 New (mu, sigma) = (1064.2220166048146, 10)
# 33 n_stockout:        342.9503 | n_holding:        218.9901 | stockout_cost:        685.9006 | holding_cost:        218.9901 | total_cost:        904.8907 | service_level:          0.5000
# 21 Out of control 1024.7792422238908 New (mu, sigma) = (1005.9802303408105, 10)
# 22 Out of control 1024.5081813325248 New (mu, sigma) = (1024.5081813325248, 10)
# 35 Out of control 1044.5081813325248 New (mu, sigma) = (1033.5167093853047, 10)
# 41 Out of control 1044.3882300541513 New (mu, sigma) = (1045.7857657387674, 10)
# 49 Out of control 1067.5244344950656 New (mu, sigma) = (1061.0658827589277, 10)
# 34 n_stockout:        385.2178 | n_holding:        160.4319 | stockout_cost:        770.4356 | holding_cost:        160.4319 | total_cost:        930.8675 | service_level:          0.3654
# 20 Out of control 1031.6942839731958 New (mu, sigma) = (1004.5393893167378, 10)
# 21 Out of control 1011.9799071643462 New (mu, sigma) = (1011.9799071643462, 10)
# 30 Out of control 1025.7840216523246 New (mu, sigma) = (1023.8919043967952, 10)
# 33 Out of control 1051.6942839731958 New (mu, sigma) = (1050.4118204882218, 10)
# 34 Out of control 1031.9799071643463 New (mu, sigma) = (1031.9799071643463, 10)
# 43 Out of control 1045.7840216523246 New (mu, sigma) = (1043.8919043967953, 10)
# 46 Out of control 1071.6942839731958 New (mu, sigma) = (1070.4118204882218, 10)
# 47 Out of control 1051.9799071643463 New (mu, sigma) = (1051.9799071643463, 10)
# 35 n_stockout:        437.8388 | n_holding:        201.1194 | stockout_cost:        875.6777 | holding_cost:        201.1194 | total_cost:       1076.7971 | service_level:          0.3462
# 15 Out of control 1014.8812375495098 New (mu, sigma) = (1002.678234880056, 10)
# 16 Out of control 1031.501946353776 New (mu, sigma) = (1031.501946353776, 10)
# 40 Out of control 1075.2109918593392 New (mu, sigma) = (1031.066983671905, 10)
# 41 Out of control 1054.88123754951 New (mu, sigma) = (1054.88123754951, 10)
# 36 n_stockout:        274.4963 | n_holding:        413.0972 | stockout_cost:        548.9926 | holding_cost:        413.0972 | total_cost:        962.0898 | service_level:          0.6346
# 15 Out of control 1023.4664702595843 New (mu, sigma) = (1007.1169294425683, 10)
# 16 Out of control 1006.9965382904599 New (mu, sigma) = (1006.9965382904599, 10)
# 18 Out of control 1029.8982370553501 New (mu, sigma) = (1032.5416779220488, 10)
# 41 Out of control 1063.4664702595844 New (mu, sigma) = (1039.840522540354, 10)
# 42 Out of control 1046.99653829046 New (mu, sigma) = (1046.99653829046, 10)
# 44 Out of control 1069.8982370553501 New (mu, sigma) = (1072.5416779220488, 10)
# 37 n_stockout:        359.2645 | n_holding:        257.6128 | stockout_cost:        718.5290 | holding_cost:        257.6128 | total_cost:        976.1418 | service_level:          0.4615
# 15 Out of control 1021.2774641529118 New (mu, sigma) = (1004.754479296802, 10)
# 16 Out of control 1022.7977291217985 New (mu, sigma) = (1022.7977291217985, 10)
# 30 Out of control 1052.8873157831667 New (mu, sigma) = (1028.6304069584767, 10)
# 31 Out of control 1056.2529631323175 New (mu, sigma) = (1056.2529631323175, 10)
# 38 n_stockout:        283.3772 | n_holding:        393.2142 | stockout_cost:        566.7543 | holding_cost:        393.2142 | total_cost:        959.9685 | service_level:          0.5577
# 14 Out of control 1022.2112104123995 New (mu, sigma) = (1004.0166479662392, 10)
# 15 Out of control 1018.546726934694 New (mu, sigma) = (1018.546726934694, 10)
# 16 Out of control 1021.2319916869047 New (mu, sigma) = (1021.2319916869047, 10)
# 27 Out of control 1042.2112104123996 New (mu, sigma) = (1024.0192177090337, 10)
# 28 Out of control 1038.546726934694 New (mu, sigma) = (1038.546726934694, 10)
# 29 Out of control 1041.2319916869046 New (mu, sigma) = (1041.2319916869046, 10)
# 40 Out of control 1062.2112104123996 New (mu, sigma) = (1044.0192177090337, 10)
# 41 Out of control 1058.546726934694 New (mu, sigma) = (1058.546726934694, 10)
# 42 Out of control 1061.2319916869046 New (mu, sigma) = (1061.2319916869046, 10)
# 39 n_stockout:        272.5968 | n_holding:        346.5016 | stockout_cost:        545.1937 | holding_cost:        346.5016 | total_cost:        891.6952 | service_level:          0.5000
# 17 Out of control 1001.5559896594972 New (mu, sigma) = (1005.7291411454376, 10)
# 20 Out of control 1024.8881005439557 New (mu, sigma) = (1027.7143265782333, 10)
# 21 Out of control 1027.1026699066067 New (mu, sigma) = (1027.1026699066067, 10)
# 33 Out of control 1044.8881005439557 New (mu, sigma) = (1034.946803189255, 10)
# 34 Out of control 1047.1026699066067 New (mu, sigma) = (1047.1026699066067, 10)
# 46 Out of control 1064.8881005439557 New (mu, sigma) = (1054.946803189255, 10)
# 47 Out of control 1067.1026699066067 New (mu, sigma) = (1067.1026699066067, 10)
# 40 n_stockout:        318.1587 | n_holding:        169.9497 | stockout_cost:        636.3173 | holding_cost:        169.9497 | total_cost:        806.2671 | service_level:          0.4423
# 16 Out of control 1010.7480003472192 New (mu, sigma) = (1001.1708280947652, 10)
# 18 Out of control 1009.5981978391707 New (mu, sigma) = (1017.6348172210148, 10)
# 19 Out of control 1018.4632404854207 New (mu, sigma) = (1018.4632404854207, 10)
# 29 Out of control 1030.7480003472192 New (mu, sigma) = (1023.4576566883679, 10)
# 30 Out of control 1045.671436602859 New (mu, sigma) = (1045.671436602859, 10)
# 41 n_stockout:        248.3891 | n_holding:        306.2962 | stockout_cost:        496.7782 | holding_cost:        306.2962 | total_cost:        803.0744 | service_level:          0.5192
# 16 Out of control 1035.2302985640802 New (mu, sigma) = (1008.4250554050116, 10)
# 17 Out of control 1017.6584662527666 New (mu, sigma) = (1017.6584662527666, 10)
# 28 Out of control 1046.476885381007 New (mu, sigma) = (1027.7314086004421, 10)
# 29 Out of control 1055.2302985640802 New (mu, sigma) = (1055.2302985640802, 10)
# 30 Out of control 1037.6584662527666 New (mu, sigma) = (1037.6584662527666, 10)
# 41 Out of control 1066.476885381007 New (mu, sigma) = (1047.7314086004421, 10)
# 42 Out of control 1075.2302985640802 New (mu, sigma) = (1075.2302985640802, 10)
# 43 Out of control 1057.6584662527666 New (mu, sigma) = (1057.6584662527666, 10)
# 42 n_stockout:        367.7693 | n_holding:        164.1129 | stockout_cost:        735.5386 | holding_cost:        164.1129 | total_cost:        899.6515 | service_level:          0.4038
# 18 Out of control 1015.8699001768528 New (mu, sigma) = (1006.0701999380195, 10)
# 20 Out of control 1040.10199247572 New (mu, sigma) = (1032.5419391602964, 10)
# 35 Out of control 1035.6078514313238 New (mu, sigma) = (1034.3176422789338, 10)
# 42 Out of control 1054.6508440122443 New (mu, sigma) = (1046.965312638978, 10)
# 43 Out of control 1068.5807334607161 New (mu, sigma) = (1068.5807334607161, 10)
# 43 n_stockout:        321.5279 | n_holding:        295.4976 | stockout_cost:        643.0558 | holding_cost:        295.4976 | total_cost:        938.5534 | service_level:          0.5192
# 15 Out of control 1032.4614002864344 New (mu, sigma) = (1003.0987638664099, 10)
# 16 Out of control 1003.9508425874141 New (mu, sigma) = (1003.9508425874141, 10)
# 17 Out of control 1005.318563210201 New (mu, sigma) = (1005.318563210201, 10)
# 20 Out of control 1020.8758797626581 New (mu, sigma) = (1020.7710040326833, 10)
# 28 Out of control 1052.4614002864344 New (mu, sigma) = (1027.4848722007373, 10)
# 29 Out of control 1023.9508425874141 New (mu, sigma) = (1023.9508425874141, 10)
# 30 Out of control 1025.3185632102009 New (mu, sigma) = (1025.3185632102009, 10)
# 33 Out of control 1040.875879762658 New (mu, sigma) = (1040.771004032683, 10)
# 41 Out of control 1072.4614002864344 New (mu, sigma) = (1047.4848722007373, 10)
# 42 Out of control 1043.950842587414 New (mu, sigma) = (1043.950842587414, 10)
# 43 Out of control 1045.3185632102009 New (mu, sigma) = (1045.3185632102009, 10)
# 46 Out of control 1060.875879762658 New (mu, sigma) = (1060.771004032683, 10)
# 44 n_stockout:        345.5689 | n_holding:        297.6807 | stockout_cost:        691.1378 | holding_cost:        297.6807 | total_cost:        988.8185 | service_level:          0.5769
# 17 Out of control 1007.2836734528059 New (mu, sigma) = (1002.083615334349, 10)
# 23 Out of control 1019.8431529244401 New (mu, sigma) = (1016.888318551119, 10)
# 28 Out of control 1036.0485445848221 New (mu, sigma) = (1029.355665315835, 10)
# 40 Out of control 1062.6032170142264 New (mu, sigma) = (1039.7750298086241, 10)
# 41 Out of control 1056.0485445848221 New (mu, sigma) = (1056.0485445848221, 10)
# 42 Out of control 1057.9569909496174 New (mu, sigma) = (1057.9569909496174, 10)
# 45 n_stockout:        331.5788 | n_holding:        248.8092 | stockout_cost:        663.1577 | holding_cost:        248.8092 | total_cost:        911.9669 | service_level:          0.4615
# 15 Out of control 1028.219002640012 New (mu, sigma) = (1007.2231114570964, 10)
# 16 Out of control 1012.0077164280355 New (mu, sigma) = (1012.0077164280355, 10)
# 27 Out of control 1052.3119574044056 New (mu, sigma) = (1026.2693950729429, 10)
# 28 Out of control 1048.219002640012 New (mu, sigma) = (1048.219002640012, 10)
# 42 Out of control 1052.0077164280356 New (mu, sigma) = (1047.2284129498896, 10)
# 46 n_stockout:        376.1175 | n_holding:        189.0346 | stockout_cost:        752.2350 | holding_cost:        189.0346 | total_cost:        941.2695 | service_level:          0.4038
# 15 Out of control 1029.2420796621802 New (mu, sigma) = (1004.9059207539684, 10)
# 16 Out of control 1026.4041180123309 New (mu, sigma) = (1026.4041180123309, 10)
# 17 Out of control 1009.4526301707258 New (mu, sigma) = (1009.4526301707258, 10)
# 19 Out of control 1009.8721324951224 New (mu, sigma) = (1023.9248698231884, 10)
# 29 Out of control 1046.4041180123309 New (mu, sigma) = (1028.7371313762383, 10)
# 30 Out of control 1029.4526301707258 New (mu, sigma) = (1029.4526301707258, 10)
# 32 Out of control 1029.8721324951225 New (mu, sigma) = (1043.9248698231886, 10)
# 42 Out of control 1066.4041180123309 New (mu, sigma) = (1048.7371313762385, 10)
# 43 Out of control 1049.4526301707258 New (mu, sigma) = (1049.4526301707258, 10)
# 45 Out of control 1049.8721324951225 New (mu, sigma) = (1063.9248698231886, 10)
# 47 n_stockout:        333.8949 | n_holding:        326.7251 | stockout_cost:        667.7899 | holding_cost:        326.7251 | total_cost:        994.5150 | service_level:          0.4808
# 17 Out of control 1018.4259584861342 New (mu, sigma) = (1004.5443969649111, 10)
# 19 Out of control 999.2514598145445 New (mu, sigma) = (1015.0943723006928, 10)
# 20 Out of control 1027.0063300880981 New (mu, sigma) = (1027.0063300880981, 10)
# 35 Out of control 1036.0266588924212 New (mu, sigma) = (1034.1654283745472, 10)
# 36 Out of control 1063.2379694608653 New (mu, sigma) = (1063.2379694608653, 10)
# 48 n_stockout:        304.9137 | n_holding:        382.0715 | stockout_cost:        609.8274 | holding_cost:        382.0715 | total_cost:        991.8988 | service_level:          0.5000
# 17 Out of control 1005.5841658973798 New (mu, sigma) = (1006.4565489405928, 10)
# 18 Out of control 1022.3380803470969 New (mu, sigma) = (1022.3380803470969, 10)
# 30 Out of control 1025.5841658973798 New (mu, sigma) = (1030.1715046004488, 10)
# 31 Out of control 1042.338080347097 New (mu, sigma) = (1042.338080347097, 10)
# 43 Out of control 1045.5841658973798 New (mu, sigma) = (1050.1715046004488, 10)
# 44 Out of control 1062.338080347097 New (mu, sigma) = (1062.338080347097, 10)
# 49 n_stockout:        311.5348 | n_holding:        177.2085 | stockout_cost:        623.0695 | holding_cost:        177.2085 | total_cost:        800.2780 | service_level:          0.5000
# 18 Out of control 1015.2326785652205 New (mu, sigma) = (1003.0958137144331, 10)
# 19 Out of control 1012.1953078610335 New (mu, sigma) = (1012.1953078610335, 10)
# 29 Out of control 1025.354195147984 New (mu, sigma) = (1024.4689259359407, 10)
# 31 Out of control 1035.2326785652206 New (mu, sigma) = (1044.6760698915446, 10)
# 50 n_stockout:        348.7338 | n_holding:        215.2733 | stockout_cost:        697.4675 | holding_cost:        215.2733 | total_cost:        912.7408 | service_level:          0.4038
# 16 Out of control 1006.3911002887786 New (mu, sigma) = (1003.473256431092, 10)
# 17 Out of control 1020.9993288230856 New (mu, sigma) = (1020.9993288230856, 10)
# 29 Out of control 1026.3911002887785 New (mu, sigma) = (1025.0775608542933, 10)
# 30 Out of control 1040.9993288230855 New (mu, sigma) = (1040.9993288230855, 10)
# 42 Out of control 1046.3911002887785 New (mu, sigma) = (1045.0775608542933, 10)
# 43 Out of control 1060.9993288230855 New (mu, sigma) = (1060.9993288230855, 10)
# 51 n_stockout:        299.6214 | n_holding:        341.4862 | stockout_cost:        599.2428 | holding_cost:        341.4862 | total_cost:        940.7290 | service_level:          0.6154
# 19 Out of control 1032.7913226405278 New (mu, sigma) = (1008.8452113617774, 10)
# 20 Out of control 1026.5973637438153 New (mu, sigma) = (1026.5973637438153, 10)
# 34 Out of control 1035.4461912385977 New (mu, sigma) = (1034.8978454274977, 10)
# 40 Out of control 1047.312496192451 New (mu, sigma) = (1049.967793645562, 10)
# 52 n_stockout:        432.1045 | n_holding:        103.8293 | stockout_cost:        864.2091 | holding_cost:        103.8293 | total_cost:        968.0383 | service_level:          0.2692
# 15 Out of control 999.2736022142565 New (mu, sigma) = (1002.4858179080645, 10)
# 16 Out of control 1013.6731282692367 New (mu, sigma) = (1013.6731282692367, 10)
# 19 Out of control 1014.5876632732517 New (mu, sigma) = (1029.5014885721328, 10)
# 20 Out of control 1027.5270542050328 New (mu, sigma) = (1027.5270542050328, 10)
# 32 Out of control 1034.5876632732518 New (mu, sigma) = (1029.9371803624547, 10)
# 33 Out of control 1047.5270542050328 New (mu, sigma) = (1047.5270542050328, 10)
# 45 Out of control 1054.5876632732518 New (mu, sigma) = (1049.9371803624547, 10)
# 46 Out of control 1067.5270542050328 New (mu, sigma) = (1067.5270542050328, 10)
# 53 n_stockout:        322.1911 | n_holding:        430.2421 | stockout_cost:        644.3823 | holding_cost:        430.2421 | total_cost:       1074.6243 | service_level:          0.5577
# 19 Out of control 1005.2902144443083 New (mu, sigma) = (1001.6479744871965, 10)
# 20 Out of control 1003.2458044824791 New (mu, sigma) = (1003.2458044824791, 10)
# 24 Out of control 1021.8552944679147 New (mu, sigma) = (1021.9216278424367, 10)
# 32 Out of control 1025.2902144443083 New (mu, sigma) = (1030.6536767933853, 10)
# 33 Out of control 1023.2458044824791 New (mu, sigma) = (1023.2458044824791, 10)
# 37 Out of control 1041.8552944679147 New (mu, sigma) = (1041.921627842437, 10)
# 45 Out of control 1045.2902144443083 New (mu, sigma) = (1050.6536767933853, 10)
# 46 Out of control 1043.2458044824791 New (mu, sigma) = (1043.2458044824791, 10)
# 50 Out of control 1061.8552944679147 New (mu, sigma) = (1061.921627842437, 10)
# 54 n_stockout:        368.6412 | n_holding:        222.5452 | stockout_cost:        737.2825 | holding_cost:        222.5452 | total_cost:        959.8276 | service_level:          0.3846
# 18 Out of control 1016.1891361707992 New (mu, sigma) = (1004.327415859437, 10)
# 21 Out of control 1028.9757224571213 New (mu, sigma) = (1024.1229918757288, 10)
# 35 Out of control 1036.388998857442 New (mu, sigma) = (1033.7534114489795, 10)
# 43 Out of control 1062.5995267792061 New (mu, sigma) = (1051.4014563466058, 10)
# 44 Out of control 1056.1891361707992 New (mu, sigma) = (1056.1891361707992, 10)
# 55 n_stockout:        417.7896 | n_holding:        162.5896 | stockout_cost:        835.5792 | holding_cost:        162.5896 | total_cost:        998.1687 | service_level:          0.3846
# 16 Out of control 1014.8782226882443 New (mu, sigma) = (1004.9799418217214, 10)
# 17 Out of control 1017.3458014030255 New (mu, sigma) = (1017.3458014030255, 10)
# 29 Out of control 1034.8782226882443 New (mu, sigma) = (1027.1540025699803, 10)
# 30 Out of control 1037.3458014030255 New (mu, sigma) = (1037.3458014030255, 10)
# 42 Out of control 1054.8782226882443 New (mu, sigma) = (1047.1540025699803, 10)
# 43 Out of control 1057.3458014030255 New (mu, sigma) = (1057.3458014030255, 10)
# 56 n_stockout:        361.5710 | n_holding:        207.1275 | stockout_cost:        723.1421 | holding_cost:        207.1275 | total_cost:        930.2695 | service_level:          0.4423
# 18 Out of control 1042.364054064307 New (mu, sigma) = (1004.9760460794523, 10)
# 19 Out of control 993.8848805081918 New (mu, sigma) = (993.8848805081918, 10)
# 21 Out of control 1037.4616800793851 New (mu, sigma) = (1032.560886993309, 10)
# 22 Out of control 1003.1086074945 New (mu, sigma) = (1003.1086074945, 10)
# 27 Out of control 1037.9935389743248 New (mu, sigma) = (1022.029856411115, 10)
# 28 Out of control 1023.0987711005467 New (mu, sigma) = (1023.0987711005467, 10)
# 31 Out of control 1062.364054064307 New (mu, sigma) = (1049.8999619771266, 10)
# 45 Out of control 1033.8848805081918 New (mu, sigma) = (1045.639148684643, 10)
# 46 Out of control 1067.660093907233 New (mu, sigma) = (1067.660093907233, 10)
# 57 n_stockout:        445.5380 | n_holding:        463.9784 | stockout_cost:        891.0761 | holding_cost:        463.9784 | total_cost:       1355.0545 | service_level:          0.5192
# 23 Out of control 1021.7241294280643 New (mu, sigma) = (1003.0792463579928, 10)
# 24 Out of control 1007.7284362276183 New (mu, sigma) = (1007.7284362276183, 10)
# 25 Out of control 1012.891697554904 New (mu, sigma) = (1012.891697554904, 10)
# 30 Out of control 1022.956392333859 New (mu, sigma) = (1029.2331902651956, 10)
# 43 Out of control 1042.956392333859 New (mu, sigma) = (1041.327771014398, 10)
# 44 Out of control 1065.8140397605373 New (mu, sigma) = (1065.8140397605373, 10)
# 58 n_stockout:        329.1795 | n_holding:        281.4373 | stockout_cost:        658.3590 | holding_cost:        281.4373 | total_cost:        939.7964 | service_level:          0.4423
# 16 Out of control 1003.9864088958465 New (mu, sigma) = (999.4913603265304, 10)
# 17 Out of control 1026.3233670240804 New (mu, sigma) = (1026.3233670240804, 10)
# 34 Out of control 1028.7767817436052 New (mu, sigma) = (1025.6736581310047, 10)
# 41 Out of control 1064.2038343210102 New (mu, sigma) = (1043.0978744364031, 10)
# 42 Out of control 1043.9864088958464 New (mu, sigma) = (1043.9864088958464, 10)
# 47 Out of control 1048.7767817436052 New (mu, sigma) = (1057.710402530049, 10)
# 59 n_stockout:        310.6435 | n_holding:        358.3033 | stockout_cost:        621.2870 | holding_cost:        358.3033 | total_cost:        979.5903 | service_level:          0.6154
# ----------------------------------------------------------------------
#      n_stockout - mean:        338.0476, std:         56.5959
#       n_holding - mean:        263.8938, std:         94.8670
#   stockout_cost - mean:        676.0952, std:        113.1919
#    holding_cost - mean:        263.8938, std:         94.8670
#      total_cost - mean:        939.9890, std:        121.9508
#   service_level - mean:          0.4817, std:          0.0920
