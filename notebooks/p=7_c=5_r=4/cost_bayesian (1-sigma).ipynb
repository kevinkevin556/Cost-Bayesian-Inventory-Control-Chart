# %%
import sys
import pathlib
sys.path.append(str(pathlib.Path.cwd().parents[1]))

from control_chart.cost_bayesian import CostBayesianControlChart
from meter import Meter
from random_demand import stepwise_increasing

p = 7
c = 5
r = 4
meter = Meter(p, c, r)

for i in range(60):
    demand = stepwise_increasing(mu={0:1000, 13:1010, 26:1020, 39:1030}, sigma=10, n=52, random_state=i)
    control_chart = CostBayesianControlChart(mu0=1000, sigma=10, p=p, c=c, r=r, T=13, N=6, rule=3, p_=None)
    purchased = []
    for t, d in enumerate(demand):
        purchased.append(control_chart.purchase())
        control_chart.test(d, t)
    print(f"{i:>2} " , end="")
    results = meter(demand, purchased, verbose=True)
print("----------------------------------------------------------------------")
stats = meter.calculate_statistics()
# Out:
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in log
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in scalar divide
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# 16 Out of control 1032.4089319920147 New (mu, sigma) = (1011.249074851883, 10)
# 17 Out of control 1028.6755799014998 New (mu, sigma) = (1028.6755799014998, 10)
# 18 Out of control 1000.2272212012359 New (mu, sigma) = (1000.2272212012359, 10)
# 27 Out of control 1024.0015720836723 New (mu, sigma) = (1018.4774169077539, 10)
# 28 Out of control 1029.7873798410574 New (mu, sigma) = (1029.7873798410574, 10)
#  0 n_stockout:        377.0915 | n_holding:        177.0430 | stockout_cost:        754.1830 | holding_cost:        177.0430 | total_cost:        931.2260 | service_level:          0.3654
# 27 Out of control 1013.8824358634993 New (mu, sigma) = (1005.0817397074852, 10)
# 28 Out of control 1014.7182824773654 New (mu, sigma) = (1014.7182824773654, 10)
# 40 Out of control 1023.8824358634993 New (mu, sigma) = (1020.5302607231137, 10)
#  1 n_stockout:        330.3344 | n_holding:        257.5209 | stockout_cost:        660.6688 | holding_cost:        257.5209 | total_cost:        918.1897 | service_level:          0.4808
# 25 Out of control 1010.415393929984 New (mu, sigma) = (1002.3628477187499, 10)
# 30 Out of control 1002.0656441480513 New (mu, sigma) = (1014.4752289058197, 10)
# 43 Out of control 1012.0656441480513 New (mu, sigma) = (1021.2090015649039, 10)
# 51 Out of control 1030.415393929984 New (mu, sigma) = (1029.1676094768316, 10)
#  2 n_stockout:        305.5950 | n_holding:        256.3694 | stockout_cost:        611.1901 | holding_cost:        256.3694 | total_cost:        867.5595 | service_level:          0.5192
# 27 Out of control 1024.36509850512 New (mu, sigma) = (1006.1856159861002, 10)
# 28 Out of control 1020.96497468072 New (mu, sigma) = (1020.96497468072, 10)
#  3 n_stockout:        255.1878 | n_holding:        225.6543 | stockout_cost:        510.3756 | holding_cost:        225.6543 | total_cost:        736.0298 | service_level:          0.4615
# 28 Out of control 1010.0409106889314 New (mu, sigma) = (1005.2510502625839, 10)
# 40 Out of control 1034.9995133323782 New (mu, sigma) = (1021.1105247976806, 10)
# 41 Out of control 1020.0409106889314 New (mu, sigma) = (1020.0409106889314, 10)
#  4 n_stockout:        334.1066 | n_holding:        129.1482 | stockout_cost:        668.2132 | holding_cost:        129.1482 | total_cost:        797.3614 | service_level:          0.3654
# 16 Out of control 1007.4790787039692 New (mu, sigma) = (1004.0415046345246, 10)
# 29 Out of control 1017.4790787039692 New (mu, sigma) = (1013.5242472971507, 10)
# 30 Out of control 1021.0960984157819 New (mu, sigma) = (1021.0960984157819, 10)
# 42 Out of control 1027.4790787039692 New (mu, sigma) = (1023.7265930372647, 10)
#  5 n_stockout:        250.1884 | n_holding:        203.6620 | stockout_cost:        500.3767 | holding_cost:        203.6620 | total_cost:        704.0387 | service_level:          0.5577
# 24 Out of control 1016.0182224995586 New (mu, sigma) = (1006.4399600706267, 10)
# 25 Out of control 1006.6411838505776 New (mu, sigma) = (1006.6411838505776, 10)
# 33 Out of control 1004.8590677136979 New (mu, sigma) = (1017.2192382607543, 10)
# 46 Out of control 1014.8590677136979 New (mu, sigma) = (1027.6015456006248, 10)
#  6 n_stockout:        401.3214 | n_holding:        191.4465 | stockout_cost:        802.6428 | holding_cost:        191.4465 | total_cost:        994.0893 | service_level:          0.3846
# 27 Out of control 1015.3406262945916 New (mu, sigma) = (1006.8294467566132, 10)
# 28 Out of control 1020.3282016367858 New (mu, sigma) = (1020.3282016367858, 10)
#  7 n_stockout:        263.9944 | n_holding:        164.3934 | stockout_cost:        527.9887 | holding_cost:        164.3934 | total_cost:        692.3821 | service_level:          0.4231
# 8 Out of control 1007.948276393484 New (mu, sigma) = (1002.9885893669515, 10)
# 19 Out of control 1027.2783616857992 New (mu, sigma) = (1006.6148884230947, 10)
# 20 Out of control 1032.0455628455613 New (mu, sigma) = (1032.0455628455613, 10)
# 21 Out of control 1017.948276393484 New (mu, sigma) = (1017.948276393484, 10)
# 33 Out of control 1042.0455628455613 New (mu, sigma) = (1018.7341112916337, 10)
# 34 Out of control 1027.948276393484 New (mu, sigma) = (1027.948276393484, 10)
# 35 Out of control 1029.7642109640094 New (mu, sigma) = (1029.7642109640094, 10)
# 47 Out of control 1037.948276393484 New (mu, sigma) = (1029.4161167440898, 10)
#  8 n_stockout:        325.8517 | n_holding:        447.2311 | stockout_cost:        651.7034 | holding_cost:        447.2311 | total_cost:       1098.9345 | service_level:          0.5000
# 27 Out of control 1017.104559307498 New (mu, sigma) = (1004.1819716041426, 10)
# 38 Out of control 1022.9668221771141 New (mu, sigma) = (1017.9885577432786, 10)
# 39 Out of control 1030.011085547122 New (mu, sigma) = (1030.011085547122, 10)
#  9 n_stockout:        239.3708 | n_holding:        207.5131 | stockout_cost:        478.7415 | holding_cost:        207.5131 | total_cost:        686.2546 | service_level:          0.4808
# 27 Out of control 1027.1527897439842 New (mu, sigma) = (1007.7089383670863, 10)
# 28 Out of control 1004.5459970788874 New (mu, sigma) = (1004.5459970788874, 10)
# 29 Out of control 1019.9161615007148 New (mu, sigma) = (1019.9161615007148, 10)
# 10 n_stockout:        299.0126 | n_holding:        142.6380 | stockout_cost:        598.0251 | holding_cost:        142.6380 | total_cost:        740.6631 | service_level:          0.4038
# 27 Out of control 1017.1392700318371 New (mu, sigma) = (1004.0651450869098, 10)
# 28 Out of control 1015.1543486777886 New (mu, sigma) = (1015.1543486777886, 10)
# 40 Out of control 1027.139270031837 New (mu, sigma) = (1019.1200644847087, 10)
# 11 n_stockout:        236.7888 | n_holding:        218.6246 | stockout_cost:        473.5777 | holding_cost:        218.6246 | total_cost:        692.2023 | service_level:          0.4423
# 23 Out of control 1004.0217708059365 New (mu, sigma) = (1004.323171557668, 10)
# 24 Out of control 1014.7245699353575 New (mu, sigma) = (1014.7245699353575, 10)
# 36 Out of control 1014.0217708059365 New (mu, sigma) = (1019.1662961928652, 10)
# 49 Out of control 1024.0217708059365 New (mu, sigma) = (1028.8246249422878, 10)
# 50 Out of control 1034.7245699353575 New (mu, sigma) = (1034.7245699353575, 10)
# 12 n_stockout:        262.0713 | n_holding:        180.8980 | stockout_cost:        524.1426 | holding_cost:        180.8980 | total_cost:        705.0406 | service_level:          0.4423
# 20 Out of control 1018.6121137416932 New (mu, sigma) = (1007.6288610081981, 10)
# 22 Out of control 999.5462286946147 New (mu, sigma) = (1012.1665430344868, 10)
# 35 Out of control 1009.5462286946147 New (mu, sigma) = (1020.3716032842786, 10)
# 36 Out of control 1012.1101097504845 New (mu, sigma) = (1012.1101097504845, 10)
# 43 Out of control 1043.45101708451 New (mu, sigma) = (1028.7071821791853, 10)
# 44 Out of control 1035.3233788829455 New (mu, sigma) = (1035.3233788829455, 10)
# 13 n_stockout:        345.9941 | n_holding:        205.1850 | stockout_cost:        691.9883 | holding_cost:        205.1850 | total_cost:        897.1732 | service_level:          0.3654
# 27 Out of control 1020.7918602460882 New (mu, sigma) = (1005.1263169275707, 10)
# 28 Out of control 1021.7397652845617 New (mu, sigma) = (1021.7397652845617, 10)
# 14 n_stockout:        229.4782 | n_holding:        264.1341 | stockout_cost:        458.9564 | holding_cost:        264.1341 | total_cost:        723.0905 | service_level:          0.5192
# 29 Out of control 1014.9821032670225 New (mu, sigma) = (1003.9382829393943, 10)
# 40 Out of control 1033.392847060462 New (mu, sigma) = (1018.5277214614645, 10)
# 41 Out of control 1028.4409146611729 New (mu, sigma) = (1028.4409146611729, 10)
# 15 n_stockout:        242.2211 | n_holding:        203.5454 | stockout_cost:        484.4421 | holding_cost:        203.5454 | total_cost:        687.9876 | service_level:          0.4615
# 38 Out of control 1011.6059568677374 New (mu, sigma) = (1005.4256785789418, 10)
# 39 Out of control 1031.2794872113393 New (mu, sigma) = (1031.2794872113393, 10)
# 16 n_stockout:        208.9107 | n_holding:        271.5331 | stockout_cost:        417.8213 | holding_cost:        271.5331 | total_cost:        689.3544 | service_level:          0.5962
# 19 Out of control 1008.8830170987123 New (mu, sigma) = (1006.9297540514733, 10)
# 20 Out of control 1006.3789866160096 New (mu, sigma) = (1006.3789866160096, 10)
# 31 Out of control 1038.866389297816 New (mu, sigma) = (1019.391205828619, 10)
# 32 Out of control 1018.8830170987123 New (mu, sigma) = (1018.8830170987123, 10)
# 44 Out of control 1048.866389297816 New (mu, sigma) = (1028.306854227568, 10)
# 45 Out of control 1028.8830170987123 New (mu, sigma) = (1028.8830170987123, 10)
# 46 Out of control 1026.3789866160096 New (mu, sigma) = (1026.3789866160096, 10)
# 17 n_stockout:        409.2407 | n_holding:        211.1286 | stockout_cost:        818.4814 | holding_cost:        211.1286 | total_cost:       1029.6100 | service_level:          0.4231
# 15 Out of control 1008.6510785339173 New (mu, sigma) = (1006.695914986715, 10)
# 28 Out of control 1018.6510785339173 New (mu, sigma) = (1016.5990194801014, 10)
# 29 Out of control 1021.6051798245487 New (mu, sigma) = (1021.6051798245487, 10)
# 41 Out of control 1028.6510785339174 New (mu, sigma) = (1027.0151727847308, 10)
# 18 n_stockout:        228.2421 | n_holding:         82.1311 | stockout_cost:        456.4842 | holding_cost:         82.1311 | total_cost:        538.6152 | service_level:          0.3269
# 33 Out of control 1025.8075341108588 New (mu, sigma) = (1006.7691019886763, 10)
# 34 Out of control 1022.5241373645007 New (mu, sigma) = (1022.5241373645007, 10)
# 19 n_stockout:        249.3836 | n_holding:        196.0966 | stockout_cost:        498.7672 | holding_cost:        196.0966 | total_cost:        694.8638 | service_level:          0.4808
# 28 Out of control 1023.5753651588528 New (mu, sigma) = (1005.9972942939502, 10)
# 29 Out of control 996.5673809435979 New (mu, sigma) = (996.5673809435979, 10)
# 32 Out of control 1029.3946934985609 New (mu, sigma) = (1021.3811101731422, 10)
# 20 n_stockout:        298.7850 | n_holding:        205.6065 | stockout_cost:        597.5700 | holding_cost:        205.6065 | total_cost:        803.1765 | service_level:          0.4808
# 26 Out of control 1019.4803575049447 New (mu, sigma) = (1006.7976382294167, 10)
# 27 Out of control 1018.8880394964558 New (mu, sigma) = (1018.8880394964558, 10)
# 21 n_stockout:        334.7660 | n_holding:        170.7431 | stockout_cost:        669.5321 | holding_cost:        170.7431 | total_cost:        840.2751 | service_level:          0.3654
# 29 Out of control 1017.6067483180243 New (mu, sigma) = (1005.4689046558025, 10)
# 42 Out of control 1027.6067483180243 New (mu, sigma) = (1021.5844415496475, 10)
# 43 Out of control 1025.0887086376158 New (mu, sigma) = (1025.0887086376158, 10)
# 22 n_stockout:        322.1348 | n_holding:        137.1120 | stockout_cost:        644.2697 | holding_cost:        137.1120 | total_cost:        781.3816 | service_level:          0.3462
# 27 Out of control 1020.2581308106627 New (mu, sigma) = (1006.3934728480516, 10)
# 31 Out of control 1009.4891843609288 New (mu, sigma) = (1019.5540116001088, 10)
# 23 n_stockout:        312.0384 | n_holding:        168.4923 | stockout_cost:        624.0769 | holding_cost:        168.4923 | total_cost:        792.5692 | service_level:          0.4231
# 25 Out of control 1019.6153839867832 New (mu, sigma) = (1004.7888262097115, 10)
# 26 Out of control 1033.2921217264918 New (mu, sigma) = (1033.2921217264918, 10)
# 24 n_stockout:        178.9518 | n_holding:        471.0029 | stockout_cost:        357.9036 | holding_cost:        471.0029 | total_cost:        828.9066 | service_level:          0.6538
# 26 Out of control 1022.2827308966608 New (mu, sigma) = (1005.4019051407, 10)
# 27 Out of control 1030.26890303163 New (mu, sigma) = (1030.26890303163, 10)
# 25 n_stockout:        227.9331 | n_holding:        416.6295 | stockout_cost:        455.8663 | holding_cost:        416.6295 | total_cost:        872.4958 | service_level:          0.6346
# 30 Out of control 1017.7113787895368 New (mu, sigma) = (1005.6228887144023, 10)
# 31 Out of control 1022.7175082598039 New (mu, sigma) = (1022.7175082598039, 10)
# 26 n_stockout:        248.3366 | n_holding:        251.7053 | stockout_cost:        496.6731 | holding_cost:        251.7053 | total_cost:        748.3784 | service_level:          0.4615
# 27 Out of control 1016.9644662269385 New (mu, sigma) = (1009.7385262709992, 10)
# 40 Out of control 1026.9644662269384 New (mu, sigma) = (1025.1099313541813, 10)
# 27 n_stockout:        378.2182 | n_holding:         39.2900 | stockout_cost:        756.4364 | holding_cost:         39.2900 | total_cost:        795.7264 | service_level:          0.1923
# 28 Out of control 1017.3572003817623 New (mu, sigma) = (1005.9849964708359, 10)
# 29 Out of control 1010.3216507062622 New (mu, sigma) = (1010.3216507062622, 10)
# 41 Out of control 1027.3572003817621 New (mu, sigma) = (1021.8504113154657, 10)
# 42 Out of control 1020.3216507062622 New (mu, sigma) = (1020.3216507062622, 10)
# 28 n_stockout:        328.1449 | n_holding:        176.6069 | stockout_cost:        656.2899 | holding_cost:        176.6069 | total_cost:        832.8967 | service_level:          0.4038
# 16 Out of control 988.5824450427 New (mu, sigma) = (1002.71981408177, 10)
# 29 Out of control 998.5824450427 New (mu, sigma) = (1013.5083882787433, 10)
# 30 Out of control 1027.1905689020487 New (mu, sigma) = (1027.1905689020487, 10)
# 29 n_stockout:        247.1225 | n_holding:        288.5324 | stockout_cost:        494.2450 | holding_cost:        288.5324 | total_cost:        782.7775 | service_level:          0.4808
# 28 Out of control 1010.2928906199114 New (mu, sigma) = (1006.1528403033093, 10)
# 29 Out of control 1024.7055961588642 New (mu, sigma) = (1024.7055961588642, 10)
# 30 n_stockout:        267.8436 | n_holding:        270.4958 | stockout_cost:        535.6871 | holding_cost:        270.4958 | total_cost:        806.1829 | service_level:          0.5192
# 34 Out of control 1012.9439968915392 New (mu, sigma) = (1006.5588162844233, 10)
# 35 Out of control 1019.1395796643105 New (mu, sigma) = (1019.1395796643105, 10)
# 31 n_stockout:        261.6137 | n_holding:        137.8024 | stockout_cost:        523.2273 | holding_cost:        137.8024 | total_cost:        661.0297 | service_level:          0.4808
# 21 Out of control 1007.3882287867281 New (mu, sigma) = (1010.1822012521013, 10)
# 22 Out of control 1003.1132318709691 New (mu, sigma) = (1003.1132318709691, 10)
# 26 Out of control 1016.5110554901057 New (mu, sigma) = (1019.2550523416289, 10)
# 27 Out of control 1029.837034333518 New (mu, sigma) = (1029.837034333518, 10)
# 32 n_stockout:        305.1270 | n_holding:        191.8226 | stockout_cost:        610.2540 | holding_cost:        191.8226 | total_cost:        802.0765 | service_level:          0.3654
# 34 Out of control 1019.0321584169009 New (mu, sigma) = (1006.6887846724793, 10)
# 35 Out of control 1024.2220166048146 New (mu, sigma) = (1024.2220166048146, 10)
# 33 n_stockout:        249.3295 | n_holding:        194.8386 | stockout_cost:        498.6589 | holding_cost:        194.8386 | total_cost:        693.4976 | service_level:          0.5385
# 34 Out of control 1024.7792422238908 New (mu, sigma) = (1006.7794939859084, 10)
# 35 Out of control 1024.5081813325248 New (mu, sigma) = (1024.5081813325248, 10)
# 34 n_stockout:        248.8468 | n_holding:        188.8665 | stockout_cost:        497.6935 | holding_cost:        188.8665 | total_cost:        686.5600 | service_level:          0.4423
# 21 Out of control 1001.9799071643462 New (mu, sigma) = (1000.7866855825382, 10)
# 33 Out of control 1031.6942839731958 New (mu, sigma) = (1013.8552167529851, 10)
# 34 Out of control 1011.9799071643462 New (mu, sigma) = (1011.9799071643462, 10)
# 46 Out of control 1041.6942839731958 New (mu, sigma) = (1023.8552167529851, 10)
# 47 Out of control 1021.9799071643462 New (mu, sigma) = (1021.9799071643462, 10)
# 35 n_stockout:        311.8282 | n_holding:        201.6655 | stockout_cost:        623.6563 | holding_cost:        201.6655 | total_cost:        825.3218 | service_level:          0.4808
# 28 Out of control 1014.8812375495098 New (mu, sigma) = (1004.7878328998414, 10)
# 29 Out of control 1031.501946353776 New (mu, sigma) = (1031.501946353776, 10)
# 36 n_stockout:        191.0125 | n_holding:        468.8398 | stockout_cost:        382.0250 | holding_cost:        468.8398 | total_cost:        850.8648 | service_level:          0.6731
# 28 Out of control 1023.4664702595843 New (mu, sigma) = (1009.9336837021532, 10)
# 29 Out of control 1006.9965382904599 New (mu, sigma) = (1006.9965382904599, 10)
# 31 Out of control 1029.8982370553501 New (mu, sigma) = (1032.5416779220488, 10)
# 37 n_stockout:        281.0367 | n_holding:        222.9513 | stockout_cost:        562.0733 | holding_cost:        222.9513 | total_cost:        785.0246 | service_level:          0.4808
# 19 Out of control 1005.3080959841122 New (mu, sigma) = (1005.6658886385112, 10)
# 31 Out of control 1036.2529631323175 New (mu, sigma) = (1016.0525238042829, 10)
# 32 Out of control 1015.3080959841122 New (mu, sigma) = (1015.3080959841122, 10)
# 44 Out of control 1046.2529631323175 New (mu, sigma) = (1026.052523804283, 10)
# 45 Out of control 1025.3080959841122 New (mu, sigma) = (1025.3080959841122, 10)
# 38 n_stockout:        344.7095 | n_holding:        202.5757 | stockout_cost:        689.4191 | holding_cost:        202.5757 | total_cost:        891.9948 | service_level:          0.5000
# 19 Out of control 990.8339145937341 New (mu, sigma) = (1005.057516129648, 10)
# 20 Out of control 985.7747290989992 New (mu, sigma) = (985.7747290989992, 10)
# 22 Out of control 1012.0150063672609 New (mu, sigma) = (1014.2389742713917, 10)
# 23 Out of control 1008.4328681761809 New (mu, sigma) = (1008.4328681761809, 10)
# 32 Out of control 1000.8339145937341 New (mu, sigma) = (1020.1449519558896, 10)
# 33 Out of control 995.7747290989992 New (mu, sigma) = (995.7747290989992, 10)
# 35 Out of control 1022.0150063672609 New (mu, sigma) = (1024.2389742713917, 10)
# 36 Out of control 1018.4328681761809 New (mu, sigma) = (1018.4328681761809, 10)
# 45 Out of control 1010.8339145937341 New (mu, sigma) = (1030.1449519558896, 10)
# 46 Out of control 1005.7747290989992 New (mu, sigma) = (1005.7747290989992, 10)
# 48 Out of control 1032.0150063672609 New (mu, sigma) = (1034.2389742713917, 10)
# 49 Out of control 1028.432868176181 New (mu, sigma) = (1028.432868176181, 10)
# 39 n_stockout:        457.1197 | n_holding:        286.5076 | stockout_cost:        914.2395 | holding_cost:        286.5076 | total_cost:       1200.7470 | service_level:          0.3846
# 20 Out of control 1014.8881005439558 New (mu, sigma) = (1005.0603581120273, 10)
# 33 Out of control 1024.8881005439557 New (mu, sigma) = (1018.1895621675128, 10)
# 34 Out of control 1027.1026699066067 New (mu, sigma) = (1027.1026699066067, 10)
# 40 n_stockout:        274.8832 | n_holding:        157.7238 | stockout_cost:        549.7665 | holding_cost:        157.7238 | total_cost:        707.4903 | service_level:          0.4038
# 29 Out of control 1010.7480003472192 New (mu, sigma) = (1003.2737839807379, 10)
# 31 Out of control 1009.5981978391707 New (mu, sigma) = (1017.6348172210148, 10)
# 41 n_stockout:        196.3613 | n_holding:        206.3457 | stockout_cost:        392.7227 | holding_cost:        206.3457 | total_cost:        599.0684 | service_level:          0.5577
# 29 Out of control 1035.2302985640802 New (mu, sigma) = (1010.3720067102303, 10)
# 30 Out of control 1017.6584662527666 New (mu, sigma) = (1017.6584662527666, 10)
# 43 Out of control 1027.6584662527666 New (mu, sigma) = (1026.7641738016698, 10)
# 42 n_stockout:        346.3004 | n_holding:         92.5870 | stockout_cost:        692.6007 | holding_cost:         92.5870 | total_cost:        785.1877 | service_level:          0.2885
# 22 Out of control 1005.6078514313236 New (mu, sigma) = (1005.593658435629, 10)
# 23 Out of control 1006.5356210701135 New (mu, sigma) = (1006.5356210701135, 10)
# 34 Out of control 1032.6286154451766 New (mu, sigma) = (1019.489517709643, 10)
# 35 Out of control 1015.6078514313236 New (mu, sigma) = (1015.6078514313236, 10)
# 47 Out of control 1042.6286154451766 New (mu, sigma) = (1028.4100263230155, 10)
# 48 Out of control 1025.6078514313238 New (mu, sigma) = (1025.6078514313238, 10)
# 43 n_stockout:        350.9559 | n_holding:        158.3243 | stockout_cost:        701.9118 | holding_cost:        158.3243 | total_cost:        860.2361 | service_level:          0.3269
# 16 Out of control 993.9508425874141 New (mu, sigma) = (1000.7959449676455, 10)
# 28 Out of control 1032.4614002864344 New (mu, sigma) = (1011.4592127428459, 10)
# 29 Out of control 1003.9508425874141 New (mu, sigma) = (1003.9508425874141, 10)
# 30 Out of control 1005.318563210201 New (mu, sigma) = (1005.318563210201, 10)
# 33 Out of control 1020.8758797626581 New (mu, sigma) = (1020.7710040326833, 10)
# 44 n_stockout:        302.9915 | n_holding:        275.9192 | stockout_cost:        605.9829 | holding_cost:        275.9192 | total_cost:        881.9021 | service_level:          0.5385
# 30 Out of control 1007.2836734528059 New (mu, sigma) = (1003.8985154292449, 10)
# 36 Out of control 1019.8431529244401 New (mu, sigma) = (1016.888318551119, 10)
# 45 n_stockout:        296.8797 | n_holding:        204.1782 | stockout_cost:        593.7594 | holding_cost:        204.1782 | total_cost:        797.9376 | service_level:          0.4038
# 27 Out of control 1032.3119574044056 New (mu, sigma) = (1008.8050301979981, 10)
# 28 Out of control 1028.219002640012 New (mu, sigma) = (1028.219002640012, 10)
# 46 n_stockout:        244.8365 | n_holding:        229.8965 | stockout_cost:        489.6730 | holding_cost:        229.8965 | total_cost:        719.5695 | service_level:          0.5000
# 28 Out of control 1029.2420796621802 New (mu, sigma) = (1007.3506350221717, 10)
# 29 Out of control 1026.4041180123309 New (mu, sigma) = (1026.4041180123309, 10)
# 30 Out of control 1009.4526301707258 New (mu, sigma) = (1009.4526301707258, 10)
# 32 Out of control 1009.8721324951224 New (mu, sigma) = (1023.9248698231884, 10)
# 47 n_stockout:        322.2257 | n_holding:        254.7417 | stockout_cost:        644.4513 | holding_cost:        254.7417 | total_cost:        899.1930 | service_level:          0.5000
# 24 Out of control 1000.0029937012453 New (mu, sigma) = (1005.0003291373644, 10)
# 25 Out of control 1004.4085323740769 New (mu, sigma) = (1004.4085323740769, 10)
# 32 Out of control 999.2514598145445 New (mu, sigma) = (1016.0399299379557, 10)
# 33 Out of control 1027.0063300880981 New (mu, sigma) = (1027.0063300880981, 10)
# 48 n_stockout:        296.5784 | n_holding:        279.7370 | stockout_cost:        593.1568 | holding_cost:        279.7370 | total_cost:        872.8938 | service_level:          0.5000
# 24 Out of control 1007.3863783536273 New (mu, sigma) = (1006.9307331834733, 10)
# 25 Out of control 1005.5239415181334 New (mu, sigma) = (1005.5239415181334, 10)
# 30 Out of control 1005.5841658973798 New (mu, sigma) = (1018.3643490756376, 10)
# 31 Out of control 1022.3380803470969 New (mu, sigma) = (1022.3380803470969, 10)
# 50 Out of control 1027.3863783536274 New (mu, sigma) = (1029.4267633611337, 10)
# 49 n_stockout:        310.2500 | n_holding:        163.4087 | stockout_cost:        620.5000 | holding_cost:        163.4087 | total_cost:        783.9087 | service_level:          0.4808
# 31 Out of control 1015.2326785652205 New (mu, sigma) = (1004.8455364868047, 10)
# 34 Out of control 1007.1770740411048 New (mu, sigma) = (1016.6916864178673, 10)
# 50 n_stockout:        308.4106 | n_holding:        185.7372 | stockout_cost:        616.8211 | holding_cost:        185.7372 | total_cost:        802.5583 | service_level:          0.4038
# 23 Out of control 1004.9434920885249 New (mu, sigma) = (1003.8514251661578, 10)
# 24 Out of control 1004.1569079191592 New (mu, sigma) = (1004.1569079191592, 10)
# 29 Out of control 1006.3911002887786 New (mu, sigma) = (1014.8768612992432, 10)
# 36 Out of control 1014.9434920885249 New (mu, sigma) = (1020.4841206656045, 10)
# 49 Out of control 1024.9434920885249 New (mu, sigma) = (1027.071543005739, 10)
# 50 Out of control 1024.156907919159 New (mu, sigma) = (1024.156907919159, 10)
# 51 n_stockout:        252.0693 | n_holding:        214.6233 | stockout_cost:        504.1387 | holding_cost:        214.6233 | total_cost:        718.7620 | service_level:          0.5000
# 27 Out of control 1007.312496192451 New (mu, sigma) = (1008.1698051461192, 10)
# 36 Out of control 1015.8107327446222 New (mu, sigma) = (1022.6428339869108, 10)
# 52 n_stockout:        362.4957 | n_holding:         87.1501 | stockout_cost:        724.9914 | holding_cost:         87.1501 | total_cost:        812.1415 | service_level:          0.3077
# 19 Out of control 1004.5876632732517 New (mu, sigma) = (1003.5975340257335, 10)
# 20 Out of control 1017.5270542050329 New (mu, sigma) = (1017.5270542050329, 10)
# 45 Out of control 1024.5876632732518 New (mu, sigma) = (1019.4407753161578, 10)
# 46 Out of control 1037.5270542050328 New (mu, sigma) = (1037.5270542050328, 10)
# 53 n_stockout:        260.8744 | n_holding:        406.6096 | stockout_cost:        521.7488 | holding_cost:        406.6096 | total_cost:        928.3584 | service_level:          0.5769
# 32 Out of control 1005.2902144443083 New (mu, sigma) = (1003.0036733316134, 10)
# 33 Out of control 1003.2458044824791 New (mu, sigma) = (1003.2458044824791, 10)
# 37 Out of control 1021.8552944679147 New (mu, sigma) = (1021.9216278424367, 10)
# 54 n_stockout:        250.3897 | n_holding:        272.6107 | stockout_cost:        500.7794 | holding_cost:        272.6107 | total_cost:        773.3901 | service_level:          0.5000
# 31 Out of control 1016.1891361707992 New (mu, sigma) = (1006.5118644611742, 10)
# 35 Out of control 1016.388998857442 New (mu, sigma) = (1022.1894936211571, 10)
# 55 n_stockout:        335.3107 | n_holding:        175.7332 | stockout_cost:        670.6214 | holding_cost:        175.7332 | total_cost:        846.3546 | service_level:          0.4038
# 25 Out of control 1005.3844104818668 New (mu, sigma) = (1005.2456794032915, 10)
# 29 Out of control 1014.8782226882443 New (mu, sigma) = (1020.3662946816185, 10)
# 51 Out of control 1025.3844104818668 New (mu, sigma) = (1026.1328402617776, 10)
# 56 n_stockout:        280.4979 | n_holding:        180.7419 | stockout_cost:        560.9958 | holding_cost:        180.7419 | total_cost:        741.7377 | service_level:          0.3846
# 19 Out of control 983.8848805081918 New (mu, sigma) = (1000.9214878008892, 10)
# 20 Out of control 1017.660093907233 New (mu, sigma) = (1017.660093907233, 10)
# 45 Out of control 1003.8848805081918 New (mu, sigma) = (1017.6986523298557, 10)
# 46 Out of control 1037.660093907233 New (mu, sigma) = (1037.660093907233, 10)
# 57 n_stockout:        263.1513 | n_holding:        495.2997 | stockout_cost:        526.3026 | holding_cost:        495.2997 | total_cost:       1021.6023 | service_level:          0.5962
# 36 Out of control 1021.7241294280643 New (mu, sigma) = (1003.274673939973, 10)
# 37 Out of control 1007.7284362276183 New (mu, sigma) = (1007.7284362276183, 10)
# 38 Out of control 1012.891697554904 New (mu, sigma) = (1012.891697554904, 10)
# 50 Out of control 1017.7284362276183 New (mu, sigma) = (1023.6974438026895, 10)
# 58 n_stockout:        262.6184 | n_holding:        226.9534 | stockout_cost:        525.2368 | holding_cost:        226.9534 | total_cost:        752.1902 | service_level:          0.4808
# 29 Out of control 1003.9864088958465 New (mu, sigma) = (1001.8525556050641, 10)
# 30 Out of control 1026.3233670240804 New (mu, sigma) = (1026.3233670240804, 10)
# 59 n_stockout:        180.8141 | n_holding:        442.5414 | stockout_cost:        361.6282 | holding_cost:        442.5414 | total_cost:        804.1696 | service_level:          0.6538
# ----------------------------------------------------------------------
#      n_stockout - mean:        288.1363, std:         56.7596
#       n_holding - mean:        227.3141, std:         95.8737
#   stockout_cost - mean:        576.2726, std:        113.5193
#    holding_cost - mean:        227.3141, std:         95.8737
#      total_cost - mean:        803.5867, std:        114.5116
#   service_level - mean:          0.4603, std:          0.0929
