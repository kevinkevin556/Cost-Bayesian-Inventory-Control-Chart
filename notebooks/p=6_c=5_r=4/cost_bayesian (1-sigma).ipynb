# %%
import sys
import pathlib
sys.path.append(str(pathlib.Path.cwd().parents[1]))

from control_chart.cost_bayesian import CostBayesianControlChart
from meter import Meter
from random_demand import stepwise_increasing

p = 6
c = 5
r = 4
meter = Meter(p, c, r)

for i in range(60):
    demand = stepwise_increasing(mu={0:1000, 13:1010, 26:1020, 39:1030}, sigma=10, n=52, random_state=i)
    control_chart = CostBayesianControlChart(mu0=1000, sigma=10, p=p, c=c, r=r, T=13, N=6, rule=3, p_=None)
    purchased = []
    for t, d in enumerate(demand):
        purchased.append(control_chart.purchase())
        control_chart.test(d, t)
    print(f"{i:>2} " , end="")
    results = meter(demand, purchased, verbose=True)
print("----------------------------------------------------------------------")
stats = meter.calculate_statistics()
# Out:
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in log
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in scalar divide
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# 17 Out of control 1028.6755799014998 New (mu, sigma) = (1012.2172140213063, 10)
# 18 Out of control 1000.2272212012359 New (mu, sigma) = (1000.2272212012359, 10)
# 27 Out of control 1024.0015720836723 New (mu, sigma) = (1018.4774169077539, 10)
# 28 Out of control 1029.7873798410574 New (mu, sigma) = (1029.7873798410574, 10)
#  0 n_stockout:        545.8958 | n_holding:         94.1617 | stockout_cost:        545.8958 | holding_cost:         94.1617 | total_cost:        640.0576 | service_level:          0.2692
# 27 Out of control 1013.8824358634993 New (mu, sigma) = (1005.0817397074852, 10)
# 28 Out of control 1014.7182824773654 New (mu, sigma) = (1014.7182824773654, 10)
# 46 Out of control 1022.387930991049 New (mu, sigma) = (1022.5459146050458, 10)
#  1 n_stockout:        486.7201 | n_holding:        165.1349 | stockout_cost:        486.7201 | holding_cost:        165.1349 | total_cost:        651.8550 | service_level:          0.3269
# 25 Out of control 1010.415393929984 New (mu, sigma) = (1002.3628477187499, 10)
# 30 Out of control 1002.0656441480513 New (mu, sigma) = (1014.4752289058197, 10)
# 51 Out of control 1030.415393929984 New (mu, sigma) = (1024.2408521980192, 10)
#  2 n_stockout:        464.6789 | n_holding:        137.6049 | stockout_cost:        464.6789 | holding_cost:        137.6049 | total_cost:        602.2838 | service_level:          0.3846
# 27 Out of control 1024.36509850512 New (mu, sigma) = (1006.1856159861002, 10)
# 28 Out of control 1020.96497468072 New (mu, sigma) = (1020.96497468072, 10)
#  3 n_stockout:        387.5143 | n_holding:        134.0026 | stockout_cost:        387.5143 | holding_cost:        134.0026 | total_cost:        521.5168 | service_level:          0.3846
# 30 Out of control 1015.8169847997309 New (mu, sigma) = (1006.2914008870187, 10)
# 31 Out of control 1004.1542276488788 New (mu, sigma) = (1004.1542276488788, 10)
# 40 Out of control 1034.9995133323782 New (mu, sigma) = (1022.9354555600717, 10)
# 41 Out of control 1020.0409106889314 New (mu, sigma) = (1020.0409106889314, 10)
#  4 n_stockout:        515.0190 | n_holding:         68.5742 | stockout_cost:        515.0190 | holding_cost:         68.5742 | total_cost:        583.5932 | service_level:          0.2308
# 16 Out of control 1007.4790787039692 New (mu, sigma) = (1004.0415046345246, 10)
# 29 Out of control 1017.4790787039692 New (mu, sigma) = (1013.5242472971507, 10)
# 30 Out of control 1021.0960984157819 New (mu, sigma) = (1021.0960984157819, 10)
# 42 Out of control 1027.4790787039692 New (mu, sigma) = (1023.7265930372647, 10)
#  5 n_stockout:        372.2311 | n_holding:        101.7265 | stockout_cost:        372.2311 | holding_cost:        101.7265 | total_cost:        473.9576 | service_level:          0.3462
# 24 Out of control 1016.0182224995586 New (mu, sigma) = (1006.4399600706267, 10)
# 25 Out of control 1006.6411838505776 New (mu, sigma) = (1006.6411838505776, 10)
# 37 Out of control 1026.0182224995585 New (mu, sigma) = (1021.8482424131286, 10)
# 38 Out of control 1016.6411838505776 New (mu, sigma) = (1016.6411838505776, 10)
# 50 Out of control 1036.0182224995585 New (mu, sigma) = (1031.8482424131287, 10)
# 51 Out of control 1026.6411838505776 New (mu, sigma) = (1026.6411838505776, 10)
#  6 n_stockout:        632.5358 | n_holding:        116.7803 | stockout_cost:        632.5358 | holding_cost:        116.7803 | total_cost:        749.3161 | service_level:          0.2692
# 27 Out of control 1015.3406262945916 New (mu, sigma) = (1006.8294467566132, 10)
# 28 Out of control 1020.3282016367858 New (mu, sigma) = (1020.3282016367858, 10)
#  7 n_stockout:        412.4401 | n_holding:         88.8609 | stockout_cost:        412.4401 | holding_cost:         88.8609 | total_cost:        501.3010 | service_level:          0.2692
# 8 Out of control 1007.948276393484 New (mu, sigma) = (1002.9885893669515, 10)
# 20 Out of control 1032.0455628455613 New (mu, sigma) = (1008.7341112916337, 10)
# 21 Out of control 1017.948276393484 New (mu, sigma) = (1017.948276393484, 10)
# 34 Out of control 1027.948276393484 New (mu, sigma) = (1019.4428932225453, 10)
# 35 Out of control 1029.7642109640094 New (mu, sigma) = (1029.7642109640094, 10)
# 47 Out of control 1037.948276393484 New (mu, sigma) = (1029.4161167440898, 10)
#  8 n_stockout:        468.6280 | n_holding:        329.8002 | stockout_cost:        468.6280 | holding_cost:        329.8002 | total_cost:        798.4282 | service_level:          0.3846
# 28 Out of control 1008.8393369693558 New (mu, sigma) = (1004.3425704098396, 10)
# 38 Out of control 1022.9668221771141 New (mu, sigma) = (1018.903479820671, 10)
# 39 Out of control 1030.011085547122 New (mu, sigma) = (1030.011085547122, 10)
#  9 n_stockout:        367.4271 | n_holding:        109.9302 | stockout_cost:        367.4271 | holding_cost:        109.9302 | total_cost:        477.3572 | service_level:          0.3846
# 27 Out of control 1027.1527897439842 New (mu, sigma) = (1007.7089383670863, 10)
# 28 Out of control 1004.5459970788874 New (mu, sigma) = (1004.5459970788874, 10)
# 29 Out of control 1019.9161615007148 New (mu, sigma) = (1019.9161615007148, 10)
# 10 n_stockout:        446.8212 | n_holding:         66.4685 | stockout_cost:        446.8212 | holding_cost:         66.4685 | total_cost:        513.2897 | service_level:          0.2115
# 27 Out of control 1017.1392700318371 New (mu, sigma) = (1004.0651450869098, 10)
# 28 Out of control 1015.1543486777886 New (mu, sigma) = (1015.1543486777886, 10)
# 11 n_stockout:        413.8382 | n_holding:        128.0728 | stockout_cost:        413.8382 | holding_cost:        128.0728 | total_cost:        541.9110 | service_level:          0.3077
# 23 Out of control 1004.0217708059365 New (mu, sigma) = (1004.323171557668, 10)
# 24 Out of control 1014.7245699353575 New (mu, sigma) = (1014.7245699353575, 10)
# 36 Out of control 1014.0217708059365 New (mu, sigma) = (1019.1662961928652, 10)
# 49 Out of control 1024.0217708059365 New (mu, sigma) = (1028.8246249422878, 10)
# 50 Out of control 1034.7245699353575 New (mu, sigma) = (1034.7245699353575, 10)
# 12 n_stockout:        409.4521 | n_holding:        104.3006 | stockout_cost:        409.4521 | holding_cost:        104.3006 | total_cost:        513.7527 | service_level:          0.2885
# 21 Out of control 1024.786857374359 New (mu, sigma) = (1008.4087699339326, 10)
# 22 Out of control 999.5462286946147 New (mu, sigma) = (999.5462286946147, 10)
# 29 Out of control 1024.518123387458 New (mu, sigma) = (1014.2299097028962, 10)
# 31 Out of control 1025.3233788829455 New (mu, sigma) = (1029.3871979837277, 10)
# 13 n_stockout:        446.7283 | n_holding:        148.8410 | stockout_cost:        446.7283 | holding_cost:        148.8410 | total_cost:        595.5693 | service_level:          0.3077
# 27 Out of control 1020.7918602460882 New (mu, sigma) = (1005.1263169275707, 10)
# 28 Out of control 1021.7397652845617 New (mu, sigma) = (1021.7397652845617, 10)
# 14 n_stockout:        346.4457 | n_holding:        157.1233 | stockout_cost:        346.4457 | holding_cost:        157.1233 | total_cost:        503.5690 | service_level:          0.3846
# 31 Out of control 1002.3639474319579 New (mu, sigma) = (1004.4646288915953, 10)
# 32 Out of control 1009.0413795605529 New (mu, sigma) = (1009.0413795605529, 10)
# 42 Out of control 1024.9821032670225 New (mu, sigma) = (1022.3466938094532, 10)
# 15 n_stockout:        397.8656 | n_holding:         84.9525 | stockout_cost:        397.8656 | holding_cost:         84.9525 | total_cost:        482.8181 | service_level:          0.2885
# 38 Out of control 1011.6059568677374 New (mu, sigma) = (1005.4256785789418, 10)
# 39 Out of control 1031.2794872113393 New (mu, sigma) = (1031.2794872113393, 10)
# 16 n_stockout:        324.9779 | n_holding:        163.6222 | stockout_cost:        324.9779 | holding_cost:        163.6222 | total_cost:        488.6001 | service_level:          0.3846
# 19 Out of control 1008.8830170987123 New (mu, sigma) = (1006.9297540514733, 10)
# 20 Out of control 1006.3789866160096 New (mu, sigma) = (1006.3789866160096, 10)
# 31 Out of control 1038.866389297816 New (mu, sigma) = (1019.391205828619, 10)
# 32 Out of control 1018.8830170987123 New (mu, sigma) = (1018.8830170987123, 10)
# 45 Out of control 1028.8830170987123 New (mu, sigma) = (1028.3511744484254, 10)
# 46 Out of control 1026.3789866160096 New (mu, sigma) = (1026.3789866160096, 10)
# 17 n_stockout:        555.3120 | n_holding:        123.2661 | stockout_cost:        555.3120 | holding_cost:        123.2661 | total_cost:        678.5781 | service_level:          0.3462
# 21 Out of control 1006.6361329679839 New (mu, sigma) = (1008.6394712812485, 10)
# 28 Out of control 1018.6510785339173 New (mu, sigma) = (1018.9790749773283, 10)
# 41 Out of control 1028.6510785339174 New (mu, sigma) = (1026.5990194801013, 10)
# 18 n_stockout:        457.0641 | n_holding:         27.1096 | stockout_cost:        457.0641 | holding_cost:         27.1096 | total_cost:        484.1737 | service_level:          0.1346
# 33 Out of control 1025.8075341108588 New (mu, sigma) = (1006.7691019886763, 10)
# 34 Out of control 1022.5241373645007 New (mu, sigma) = (1022.5241373645007, 10)
# 19 n_stockout:        392.0332 | n_holding:        114.7680 | stockout_cost:        392.0332 | holding_cost:        114.7680 | total_cost:        506.8012 | service_level:          0.2885
# 28 Out of control 1023.5753651588528 New (mu, sigma) = (1005.9972942939502, 10)
# 29 Out of control 996.5673809435979 New (mu, sigma) = (996.5673809435979, 10)
# 33 Out of control 1010.215189578813 New (mu, sigma) = (1018.5896300245599, 10)
# 34 Out of control 1025.030968401092 New (mu, sigma) = (1025.030968401092, 10)
# 20 n_stockout:        421.1343 | n_holding:        138.4201 | stockout_cost:        421.1343 | holding_cost:        138.4201 | total_cost:        559.5544 | service_level:          0.3077
# 26 Out of control 1019.4803575049447 New (mu, sigma) = (1006.7976382294167, 10)
# 27 Out of control 1018.8880394964558 New (mu, sigma) = (1018.8880394964558, 10)
# 21 n_stockout:        481.7597 | n_holding:         93.7586 | stockout_cost:        481.7597 | holding_cost:         93.7586 | total_cost:        575.5183 | service_level:          0.3269
# 30 Out of control 1015.0887086376157 New (mu, sigma) = (1005.7792209132803, 10)
# 42 Out of control 1027.6067483180243 New (mu, sigma) = (1022.1257526256501, 10)
# 43 Out of control 1025.0887086376158 New (mu, sigma) = (1025.0887086376158, 10)
# 22 n_stockout:        479.6771 | n_holding:         69.4723 | stockout_cost:        479.6771 | holding_cost:         69.4723 | total_cost:        549.1494 | service_level:          0.2692
# 28 Out of control 1012.2238058680819 New (mu, sigma) = (1006.5945188142595, 10)
# 29 Out of control 1029.4863382249493 New (mu, sigma) = (1029.4863382249493, 10)
# 23 n_stockout:        332.1825 | n_holding:        203.2981 | stockout_cost:        332.1825 | holding_cost:        203.2981 | total_cost:        535.4806 | service_level:          0.4423
# 26 Out of control 1033.2921217264918 New (mu, sigma) = (1005.8445038214442, 10)
# 27 Out of control 1012.2996654799515 New (mu, sigma) = (1012.2996654799515, 10)
# 40 Out of control 1022.2996654799515 New (mu, sigma) = (1021.327287748173, 10)
# 41 Out of control 1026.8371964037858 New (mu, sigma) = (1026.8371964037858, 10)
# 24 n_stockout:        446.1518 | n_holding:        132.5722 | stockout_cost:        446.1518 | holding_cost:        132.5722 | total_cost:        578.7241 | service_level:          0.3269
# 27 Out of control 1030.26890303163 New (mu, sigma) = (1006.2900122082332, 10)
# 28 Out of control 1011.6041515103482 New (mu, sigma) = (1011.6041515103482, 10)
# 40 Out of control 1040.26890303163 New (mu, sigma) = (1022.0983502033977, 10)
# 41 Out of control 1021.6041515103482 New (mu, sigma) = (1021.6041515103482, 10)
# 25 n_stockout:        487.0879 | n_holding:        103.6302 | stockout_cost:        487.0879 | holding_cost:        103.6302 | total_cost:        590.7181 | service_level:          0.3077
# 30 Out of control 1017.7113787895368 New (mu, sigma) = (1005.6228887144023, 10)
# 31 Out of control 1022.7175082598039 New (mu, sigma) = (1022.7175082598039, 10)
# 26 n_stockout:        381.3646 | n_holding:        160.7551 | stockout_cost:        381.3646 | holding_cost:        160.7551 | total_cost:        542.1197 | service_level:          0.3462
# 27 Out of control 1016.9644662269385 New (mu, sigma) = (1009.7385262709992, 10)
# 40 Out of control 1026.9644662269384 New (mu, sigma) = (1025.1099313541813, 10)
# 27 n_stockout:        574.6108 | n_holding:         11.7044 | stockout_cost:        574.6108 | holding_cost:         11.7044 | total_cost:        586.3152 | service_level:          0.0962
# 28 Out of control 1017.3572003817623 New (mu, sigma) = (1005.9849964708359, 10)
# 29 Out of control 1010.3216507062622 New (mu, sigma) = (1010.3216507062622, 10)
# 41 Out of control 1027.3572003817621 New (mu, sigma) = (1021.8504113154657, 10)
# 42 Out of control 1020.3216507062622 New (mu, sigma) = (1020.3216507062622, 10)
# 28 n_stockout:        482.4993 | n_holding:        106.9830 | stockout_cost:        482.4993 | holding_cost:        106.9830 | total_cost:        589.4822 | service_level:          0.2115
# 29 Out of control 998.5824450427 New (mu, sigma) = (1007.3948629004583, 10)
# 30 Out of control 1027.1905689020487 New (mu, sigma) = (1027.1905689020487, 10)
# 29 n_stockout:        402.7526 | n_holding:        178.7133 | stockout_cost:        402.7526 | holding_cost:        178.7133 | total_cost:        581.4659 | service_level:          0.3654
# 28 Out of control 1010.2928906199114 New (mu, sigma) = (1006.1528403033093, 10)
# 29 Out of control 1024.7055961588642 New (mu, sigma) = (1024.7055961588642, 10)
# 30 n_stockout:        387.9211 | n_holding:        166.5952 | stockout_cost:        387.9211 | holding_cost:        166.5952 | total_cost:        554.5163 | service_level:          0.4038
# 34 Out of control 1012.9439968915392 New (mu, sigma) = (1006.5588162844233, 10)
# 35 Out of control 1019.1395796643105 New (mu, sigma) = (1019.1395796643105, 10)
# 31 n_stockout:        409.2484 | n_holding:         61.4589 | stockout_cost:        409.2484 | holding_cost:         61.4589 | total_cost:        470.7073 | service_level:          0.2308
# 21 Out of control 1007.3882287867281 New (mu, sigma) = (1010.1822012521013, 10)
# 22 Out of control 1003.1132318709691 New (mu, sigma) = (1003.1132318709691, 10)
# 26 Out of control 1016.5110554901057 New (mu, sigma) = (1019.2550523416289, 10)
# 27 Out of control 1029.837034333518 New (mu, sigma) = (1029.837034333518, 10)
# 32 n_stockout:        448.8357 | n_holding:        111.5530 | stockout_cost:        448.8357 | holding_cost:        111.5530 | total_cost:        560.3887 | service_level:          0.3269
# 34 Out of control 1019.0321584169009 New (mu, sigma) = (1006.6887846724793, 10)
# 35 Out of control 1024.2220166048146 New (mu, sigma) = (1024.2220166048146, 10)
# 33 n_stockout:        385.4425 | n_holding:        106.9735 | stockout_cost:        385.4425 | holding_cost:        106.9735 | total_cost:        492.4160 | service_level:          0.3462
# 34 Out of control 1024.7792422238908 New (mu, sigma) = (1006.7794939859084, 10)
# 35 Out of control 1024.5081813325248 New (mu, sigma) = (1024.5081813325248, 10)
# 34 n_stockout:        390.7812 | n_holding:        106.8227 | stockout_cost:        390.7812 | holding_cost:        106.8227 | total_cost:        497.6038 | service_level:          0.2885
# 33 Out of control 1031.6942839731958 New (mu, sigma) = (1005.3991083485782, 10)
# 34 Out of control 1011.9799071643462 New (mu, sigma) = (1011.9799071643462, 10)
# 46 Out of control 1041.6942839731958 New (mu, sigma) = (1023.8552167529851, 10)
# 47 Out of control 1021.9799071643462 New (mu, sigma) = (1021.9799071643462, 10)
# 35 n_stockout:        458.0561 | n_holding:        106.0189 | stockout_cost:        458.0561 | holding_cost:        106.0189 | total_cost:        564.0751 | service_level:          0.2885
# 28 Out of control 1014.8812375495098 New (mu, sigma) = (1004.7878328998414, 10)
# 29 Out of control 1031.501946353776 New (mu, sigma) = (1031.501946353776, 10)
# 36 n_stockout:        278.7261 | n_holding:        332.5751 | stockout_cost:        278.7261 | holding_cost:        332.5751 | total_cost:        611.3012 | service_level:          0.5577
# 28 Out of control 1023.4664702595843 New (mu, sigma) = (1009.9336837021532, 10)
# 29 Out of control 1006.9965382904599 New (mu, sigma) = (1006.9965382904599, 10)
# 31 Out of control 1029.8982370553501 New (mu, sigma) = (1032.5416779220488, 10)
# 37 n_stockout:        416.1210 | n_holding:        134.0575 | stockout_cost:        416.1210 | holding_cost:        134.0575 | total_cost:        550.1785 | service_level:          0.3269
# 19 Out of control 1005.3080959841122 New (mu, sigma) = (1005.6658886385112, 10)
# 31 Out of control 1036.2529631323175 New (mu, sigma) = (1016.0525238042829, 10)
# 32 Out of control 1015.3080959841122 New (mu, sigma) = (1015.3080959841122, 10)
# 44 Out of control 1046.2529631323175 New (mu, sigma) = (1026.052523804283, 10)
# 45 Out of control 1025.3080959841122 New (mu, sigma) = (1025.3080959841122, 10)
# 38 n_stockout:        475.9704 | n_holding:        109.8583 | stockout_cost:        475.9704 | holding_cost:        109.8583 | total_cost:        585.8287 | service_level:          0.3462
# 19 Out of control 990.8339145937341 New (mu, sigma) = (1005.057516129648, 10)
# 20 Out of control 985.7747290989992 New (mu, sigma) = (985.7747290989992, 10)
# 22 Out of control 1012.0150063672609 New (mu, sigma) = (1014.2389742713917, 10)
# 23 Out of control 1008.4328681761809 New (mu, sigma) = (1008.4328681761809, 10)
# 32 Out of control 1000.8339145937341 New (mu, sigma) = (1020.1449519558896, 10)
# 33 Out of control 995.7747290989992 New (mu, sigma) = (995.7747290989992, 10)
# 35 Out of control 1022.0150063672609 New (mu, sigma) = (1024.2389742713917, 10)
# 36 Out of control 1018.4328681761809 New (mu, sigma) = (1018.4328681761809, 10)
# 45 Out of control 1010.8339145937341 New (mu, sigma) = (1030.1449519558896, 10)
# 46 Out of control 1005.7747290989992 New (mu, sigma) = (1005.7747290989992, 10)
# 48 Out of control 1032.0150063672609 New (mu, sigma) = (1034.2389742713917, 10)
# 49 Out of control 1028.432868176181 New (mu, sigma) = (1028.432868176181, 10)
# 39 n_stockout:        600.4107 | n_holding:        205.8203 | stockout_cost:        600.4107 | holding_cost:        205.8203 | total_cost:        806.2310 | service_level:          0.3269
# 20 Out of control 1014.8881005439558 New (mu, sigma) = (1005.0603581120273, 10)
# 33 Out of control 1024.8881005439557 New (mu, sigma) = (1018.1895621675128, 10)
# 34 Out of control 1027.1026699066067 New (mu, sigma) = (1027.1026699066067, 10)
# 40 n_stockout:        427.1341 | n_holding:         85.9965 | stockout_cost:        427.1341 | holding_cost:         85.9965 | total_cost:        513.1306 | service_level:          0.2692
# 31 Out of control 1009.5981978391707 New (mu, sigma) = (1004.1713485582553, 10)
# 32 Out of control 1018.4632404854207 New (mu, sigma) = (1018.4632404854207, 10)
# 41 n_stockout:        327.7013 | n_holding:        109.4364 | stockout_cost:        327.7013 | holding_cost:        109.4364 | total_cost:        437.1377 | service_level:          0.3269
# 29 Out of control 1035.2302985640802 New (mu, sigma) = (1010.3720067102303, 10)
# 30 Out of control 1017.6584662527666 New (mu, sigma) = (1017.6584662527666, 10)
# 46 Out of control 1037.674347291529 New (mu, sigma) = (1028.691210331176, 10)
# 42 n_stockout:        532.4468 | n_holding:         37.0732 | stockout_cost:        532.4468 | holding_cost:         37.0732 | total_cost:        569.5200 | service_level:          0.2308
# 22 Out of control 1005.6078514313236 New (mu, sigma) = (1005.593658435629, 10)
# 23 Out of control 1006.5356210701135 New (mu, sigma) = (1006.5356210701135, 10)
# 34 Out of control 1032.6286154451766 New (mu, sigma) = (1019.489517709643, 10)
# 35 Out of control 1015.6078514313236 New (mu, sigma) = (1015.6078514313236, 10)
# 47 Out of control 1042.6286154451766 New (mu, sigma) = (1028.4100263230155, 10)
# 48 Out of control 1025.6078514313238 New (mu, sigma) = (1025.6078514313238, 10)
# 43 n_stockout:        507.9972 | n_holding:         91.3873 | stockout_cost:        507.9972 | holding_cost:         91.3873 | total_cost:        599.3845 | service_level:          0.2308
# 28 Out of control 1032.4614002864344 New (mu, sigma) = (1005.2083316332455, 10)
# 29 Out of control 1003.9508425874141 New (mu, sigma) = (1003.9508425874141, 10)
# 30 Out of control 1005.318563210201 New (mu, sigma) = (1005.318563210201, 10)
# 33 Out of control 1020.8758797626581 New (mu, sigma) = (1020.7710040326833, 10)
# 44 n_stockout:        419.5598 | n_holding:        152.7072 | stockout_cost:        419.5598 | holding_cost:        152.7072 | total_cost:        572.2670 | service_level:          0.4423
# 36 Out of control 1019.8431529244401 New (mu, sigma) = (1006.004969989549, 10)
# 37 Out of control 1022.5959596625333 New (mu, sigma) = (1022.5959596625333, 10)
# 45 n_stockout:        418.6011 | n_holding:        147.5539 | stockout_cost:        418.6011 | holding_cost:        147.5539 | total_cost:        566.1550 | service_level:          0.3077
# 27 Out of control 1032.3119574044056 New (mu, sigma) = (1008.8050301979981, 10)
# 28 Out of control 1028.219002640012 New (mu, sigma) = (1028.219002640012, 10)
# 46 n_stockout:        368.7113 | n_holding:        129.7931 | stockout_cost:        368.7113 | holding_cost:        129.7931 | total_cost:        498.5044 | service_level:          0.3269
# 28 Out of control 1029.2420796621802 New (mu, sigma) = (1007.3506350221717, 10)
# 29 Out of control 1026.4041180123309 New (mu, sigma) = (1026.4041180123309, 10)
# 30 Out of control 1009.4526301707258 New (mu, sigma) = (1009.4526301707258, 10)
# 32 Out of control 1009.8721324951224 New (mu, sigma) = (1023.9248698231884, 10)
# 47 n_stockout:        444.1851 | n_holding:        152.7229 | stockout_cost:        444.1851 | holding_cost:        152.7229 | total_cost:        596.9080 | service_level:          0.3846
# 24 Out of control 1000.0029937012453 New (mu, sigma) = (1005.0003291373644, 10)
# 25 Out of control 1004.4085323740769 New (mu, sigma) = (1004.4085323740769, 10)
# 32 Out of control 999.2514598145445 New (mu, sigma) = (1016.0399299379557, 10)
# 33 Out of control 1027.0063300880981 New (mu, sigma) = (1027.0063300880981, 10)
# 48 n_stockout:        413.6730 | n_holding:        172.8534 | stockout_cost:        413.6730 | holding_cost:        172.8534 | total_cost:        586.5265 | service_level:          0.4231
# 24 Out of control 1007.3863783536273 New (mu, sigma) = (1006.9307331834733, 10)
# 25 Out of control 1005.5239415181334 New (mu, sigma) = (1005.5239415181334, 10)
# 30 Out of control 1005.5841658973798 New (mu, sigma) = (1018.3643490756376, 10)
# 31 Out of control 1022.3380803470969 New (mu, sigma) = (1022.3380803470969, 10)
# 49 n_stockout:        448.7066 | n_holding:         70.7985 | stockout_cost:        448.7066 | holding_cost:         70.7985 | total_cost:        519.5051 | service_level:          0.3077
# 31 Out of control 1015.2326785652205 New (mu, sigma) = (1004.8455364868047, 10)
# 34 Out of control 1007.1770740411048 New (mu, sigma) = (1016.6916864178673, 10)
# 50 n_stockout:        452.0359 | n_holding:        105.3843 | stockout_cost:        452.0359 | holding_cost:        105.3843 | total_cost:        557.4202 | service_level:          0.2885
# 23 Out of control 1004.9434920885249 New (mu, sigma) = (1003.8514251661578, 10)
# 24 Out of control 1004.1569079191592 New (mu, sigma) = (1004.1569079191592, 10)
# 36 Out of control 1014.9434920885249 New (mu, sigma) = (1018.1477625962872, 10)
# 37 Out of control 1014.1569079191592 New (mu, sigma) = (1014.1569079191592, 10)
# 49 Out of control 1024.9434920885249 New (mu, sigma) = (1028.1477625962873, 10)
# 50 Out of control 1024.156907919159 New (mu, sigma) = (1024.156907919159, 10)
# 51 n_stockout:        505.3730 | n_holding:         91.7224 | stockout_cost:        505.3730 | holding_cost:         91.7224 | total_cost:        597.0954 | service_level:          0.3077
# 27 Out of control 1007.312496192451 New (mu, sigma) = (1008.1698051461192, 10)
# 36 Out of control 1015.8107327446222 New (mu, sigma) = (1022.6428339869108, 10)
# 52 n_stockout:        537.9692 | n_holding:         38.6454 | stockout_cost:        537.9692 | holding_cost:         38.6454 | total_cost:        576.6146 | service_level:          0.1538
# 19 Out of control 1004.5876632732517 New (mu, sigma) = (1003.5975340257335, 10)
# 20 Out of control 1017.5270542050329 New (mu, sigma) = (1017.5270542050329, 10)
# 45 Out of control 1024.5876632732518 New (mu, sigma) = (1019.4407753161578, 10)
# 46 Out of control 1037.5270542050328 New (mu, sigma) = (1037.5270542050328, 10)
# 53 n_stockout:        362.6050 | n_holding:        284.3621 | stockout_cost:        362.6050 | holding_cost:        284.3621 | total_cost:        646.9671 | service_level:          0.5192
# 32 Out of control 1005.2902144443083 New (mu, sigma) = (1003.0036733316134, 10)
# 33 Out of control 1003.2458044824791 New (mu, sigma) = (1003.2458044824791, 10)
# 38 Out of control 1008.431654802462 New (mu, sigma) = (1019.2236332344416, 10)
# 54 n_stockout:        395.3407 | n_holding:        139.8337 | stockout_cost:        395.3407 | holding_cost:        139.8337 | total_cost:        535.1745 | service_level:          0.3654
# 33 Out of control 1023.416151798288 New (mu, sigma) = (1007.4050857625778, 10)
# 34 Out of control 1028.9757224571213 New (mu, sigma) = (1028.9757224571213, 10)
# 55 n_stockout:        417.5342 | n_holding:        152.8916 | stockout_cost:        417.5342 | holding_cost:        152.8916 | total_cost:        570.4258 | service_level:          0.3269
# 29 Out of control 1014.8782226882443 New (mu, sigma) = (1007.2617614404019, 10)
# 30 Out of control 1017.3458014030255 New (mu, sigma) = (1017.3458014030255, 10)
# 51 Out of control 1025.3844104818668 New (mu, sigma) = (1026.551270683623, 10)
# 56 n_stockout:        501.0559 | n_holding:         79.8042 | stockout_cost:        501.0559 | holding_cost:         79.8042 | total_cost:        580.8601 | service_level:          0.3077
# 19 Out of control 983.8848805081918 New (mu, sigma) = (1000.9214878008892, 10)
# 20 Out of control 1017.660093907233 New (mu, sigma) = (1017.660093907233, 10)
# 45 Out of control 1003.8848805081918 New (mu, sigma) = (1017.6986523298557, 10)
# 46 Out of control 1037.660093907233 New (mu, sigma) = (1037.660093907233, 10)
# 57 n_stockout:        357.0227 | n_holding:        365.1929 | stockout_cost:        357.0227 | holding_cost:        365.1929 | total_cost:        722.2156 | service_level:          0.5385
# 36 Out of control 1021.7241294280643 New (mu, sigma) = (1003.274673939973, 10)
# 37 Out of control 1007.7284362276183 New (mu, sigma) = (1007.7284362276183, 10)
# 38 Out of control 1012.891697554904 New (mu, sigma) = (1012.891697554904, 10)
# 50 Out of control 1017.7284362276183 New (mu, sigma) = (1023.6974438026895, 10)
# 58 n_stockout:        393.4601 | n_holding:        133.8169 | stockout_cost:        393.4601 | holding_cost:        133.8169 | total_cost:        527.2770 | service_level:          0.3269
# 29 Out of control 1003.9864088958465 New (mu, sigma) = (1001.8525556050641, 10)
# 30 Out of control 1026.3233670240804 New (mu, sigma) = (1026.3233670240804, 10)
# 59 n_stockout:        272.8614 | n_holding:        310.6105 | stockout_cost:        272.8614 | holding_cost:        310.6105 | total_cost:        583.4719 | service_level:          0.5769
# ----------------------------------------------------------------------
#      n_stockout - mean:        434.8056, std:         72.1013
#       n_holding - mean:        132.6455, std:         70.4089
#   stockout_cost - mean:        434.8056, std:         72.1013
#    holding_cost - mean:        132.6455, std:         70.4089
#      total_cost - mean:        567.4511, std:         72.8618
#   service_level - mean:          0.3266, std:          0.0894
