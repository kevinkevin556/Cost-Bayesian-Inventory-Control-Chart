# %%
import sys
import pathlib
sys.path.append(str(pathlib.Path.cwd().parents[1]))

from control_chart.cost_bayesian import CostBayesianControlChart
from meter import Meter
from random_demand import stepwise_increasing

p = 6
c = 5
r = 3
meter = Meter(p, c, r)

for i in range(60):
    demand = stepwise_increasing(mu={0:1000, 13:1030, 26:1060, 39:1090}, sigma=10, n=52, random_state=i)
    control_chart = CostBayesianControlChart(mu0=1000, sigma=10, p=p, c=c, r=r, T=13, N=6, rule=3, p_=None)
    purchased = []
    for t, d in enumerate(demand):
        purchased.append(control_chart.purchase())
        control_chart.test(d, t)
    print(f"{i:>2} " , end="")
    results = meter(demand, purchased, verbose=True)
print("----------------------------------------------------------------------")
stats = meter.calculate_statistics()
# Out:
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in log
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# c:\Users\User\Desktop\Kevin\inventory\control_chart\cost_bayesian.py:161: RuntimeWarning: divide by zero encountered in scalar divide
#   xp = 0.5 * (mu0 + mu1) + sigma**2 / (mu1 - mu0) * np.log(p * L0 / ((1 - p) * L1))
# 14 Out of control 1034.0015720836723 New (mu, sigma) = (1011.9358640432628, 10)
# 15 Out of control 1039.7873798410574 New (mu, sigma) = (1039.7873798410574, 10)
# 27 Out of control 1064.0015720836723 New (mu, sigma) = (1042.3007071053783, 10)
# 28 Out of control 1069.7873798410574 New (mu, sigma) = (1069.7873798410574, 10)
# 40 Out of control 1094.0015720836723 New (mu, sigma) = (1072.3007071053783, 10)
# 41 Out of control 1099.7873798410574 New (mu, sigma) = (1099.7873798410574, 10)
#  0 n_stockout:        622.2369 | n_holding:        107.9835 | stockout_cost:        622.2369 | holding_cost:        215.9669 | total_cost:        838.2039 | service_level:          0.3077
# 14 Out of control 1023.8824358634993 New (mu, sigma) = (1003.4138200436574, 10)
# 15 Out of control 1024.7182824773654 New (mu, sigma) = (1024.7182824773654, 10)
# 27 Out of control 1053.8824358634993 New (mu, sigma) = (1033.863594056447, 10)
# 28 Out of control 1054.7182824773654 New (mu, sigma) = (1054.7182824773654, 10)
# 40 Out of control 1083.8824358634993 New (mu, sigma) = (1063.863594056447, 10)
# 41 Out of control 1084.7182824773654 New (mu, sigma) = (1084.7182824773654, 10)
#  1 n_stockout:        710.9939 | n_holding:        124.2527 | stockout_cost:        710.9939 | holding_cost:        248.5054 | total_cost:        959.4994 | service_level:          0.2885
# 15 Out of control 1008.6380390433154 New (mu, sigma) = (1001.8515507900468, 10)
# 16 Out of control 1046.40270808405 New (mu, sigma) = (1046.40270808405, 10)
# 38 Out of control 1060.415393929984 New (mu, sigma) = (1045.0510700139296, 10)
# 39 Out of control 1085.8324215259454 New (mu, sigma) = (1085.8324215259454, 10)
#  2 n_stockout:        559.8984 | n_holding:        230.8034 | stockout_cost:        559.8984 | holding_cost:        461.6068 | total_cost:       1021.5052 | service_level:          0.4038
# 14 Out of control 1034.36509850512 New (mu, sigma) = (1004.8482876950077, 10)
# 15 Out of control 1030.9649746807202 New (mu, sigma) = (1030.9649746807202, 10)
# 27 Out of control 1064.36509850512 New (mu, sigma) = (1034.1256631254143, 10)
# 28 Out of control 1060.9649746807202 New (mu, sigma) = (1060.9649746807202, 10)
# 40 Out of control 1094.36509850512 New (mu, sigma) = (1064.1256631254143, 10)
# 41 Out of control 1090.9649746807202 New (mu, sigma) = (1090.9649746807202, 10)
#  3 n_stockout:        524.5034 | n_holding:        114.5422 | stockout_cost:        524.5034 | holding_cost:        229.0845 | total_cost:        753.5879 | service_level:          0.3654
# 15 Out of control 1020.0409106889314 New (mu, sigma) = (1004.3070780846149, 10)
# 16 Out of control 1036.935985082913 New (mu, sigma) = (1036.935985082913, 10)
# 28 Out of control 1050.0409106889313 New (mu, sigma) = (1035.5359352648486, 10)
# 29 Out of control 1066.935985082913 New (mu, sigma) = (1066.935985082913, 10)
# 41 Out of control 1080.0409106889313 New (mu, sigma) = (1065.5359352648486, 10)
# 42 Out of control 1096.935985082913 New (mu, sigma) = (1096.935985082913, 10)
#  4 n_stockout:        455.7203 | n_holding:        182.5398 | stockout_cost:        455.7203 | holding_cost:        365.0795 | total_cost:        820.7998 | service_level:          0.3654
# 14 Out of control 1026.6912984810592 New (mu, sigma) = (1004.4612525475245, 10)
# 15 Out of control 1054.3077118700778 New (mu, sigma) = (1054.3077118700778, 10)
# 16 Out of control 1027.4790787039692 New (mu, sigma) = (1027.4790787039692, 10)
# 27 Out of control 1056.6912984810592 New (mu, sigma) = (1034.0025840262647, 10)
# 28 Out of control 1084.3077118700778 New (mu, sigma) = (1084.3077118700778, 10)
#  5 n_stockout:        518.5483 | n_holding:        265.4280 | stockout_cost:        518.5483 | holding_cost:        530.8560 | total_cost:       1049.4043 | service_level:          0.3269
# 15 Out of control 1032.17820788076 New (mu, sigma) = (1007.1981564493833, 10)
# 16 Out of control 1021.0090820345287 New (mu, sigma) = (1021.0090820345287, 10)
# 24 Out of control 1036.0182224995585 New (mu, sigma) = (1033.1024270676257, 10)
# 25 Out of control 1026.6411838505776 New (mu, sigma) = (1026.6411838505776, 10)
# 27 Out of control 1067.290039236125 New (mu, sigma) = (1062.0861012506248, 10)
# 28 Out of control 1062.17820788076 New (mu, sigma) = (1062.17820788076, 10)
# 41 Out of control 1092.17820788076 New (mu, sigma) = (1068.3707763698558, 10)
# 42 Out of control 1081.0090820345285 New (mu, sigma) = (1081.0090820345285, 10)
# 50 Out of control 1096.0182224995585 New (mu, sigma) = (1093.1024270676257, 10)
# 51 Out of control 1086.6411838505776 New (mu, sigma) = (1086.6411838505776, 10)
#  6 n_stockout:        810.8769 | n_holding:        113.2226 | stockout_cost:        810.8769 | holding_cost:        226.4452 | total_cost:       1037.3220 | service_level:          0.2692
# 14 Out of control 1025.3406262945916 New (mu, sigma) = (1005.1156797505923, 10)
# 15 Out of control 1030.328201636786 New (mu, sigma) = (1030.328201636786, 10)
# 27 Out of control 1055.3406262945916 New (mu, sigma) = (1035.3467592741251, 10)
# 28 Out of control 1060.328201636786 New (mu, sigma) = (1060.328201636786, 10)
# 40 Out of control 1085.3406262945916 New (mu, sigma) = (1065.3467592741251, 10)
# 41 Out of control 1090.328201636786 New (mu, sigma) = (1090.328201636786, 10)
#  7 n_stockout:        563.3491 | n_holding:         78.3817 | stockout_cost:        563.3491 | holding_cost:        156.7634 | total_cost:        720.1125 | service_level:          0.2500
# 8 Out of control 1007.948276393484 New (mu, sigma) = (1002.9885893669515, 10)
# 15 Out of control 1010.5302969097745 New (mu, sigma) = (1012.6022112856023, 10)
# 16 Out of control 1016.1365046776306 New (mu, sigma) = (1016.1365046776306, 10)
# 19 Out of control 1047.2783616857992 New (mu, sigma) = (1036.1372629923976, 10)
# 20 Out of control 1052.0455628455613 New (mu, sigma) = (1052.0455628455613, 10)
# 33 Out of control 1082.0455628455613 New (mu, sigma) = (1050.9813547610067, 10)
# 34 Out of control 1067.948276393484 New (mu, sigma) = (1067.948276393484, 10)
# 41 Out of control 1070.5302969097745 New (mu, sigma) = (1072.6022112856024, 10)
# 42 Out of control 1076.1365046776307 New (mu, sigma) = (1076.1365046776307, 10)
# 45 Out of control 1107.2783616857992 New (mu, sigma) = (1096.1372629923976, 10)
# 46 Out of control 1112.0455628455613 New (mu, sigma) = (1112.0455628455613, 10)
#  8 n_stockout:        692.2248 | n_holding:        275.8737 | stockout_cost:        692.2248 | holding_cost:        551.7474 | total_cost:       1243.9723 | service_level:          0.3846
# 15 Out of control 1018.8393369693558 New (mu, sigma) = (1003.1840476159164, 10)
# 16 Out of control 1029.8711724325422 New (mu, sigma) = (1029.8711724325422, 10)
# 28 Out of control 1048.8393369693558 New (mu, sigma) = (1035.4265506331787, 10)
# 29 Out of control 1059.8711724325422 New (mu, sigma) = (1059.8711724325422, 10)
# 41 Out of control 1078.8393369693558 New (mu, sigma) = (1065.4265506331787, 10)
# 42 Out of control 1089.8711724325422 New (mu, sigma) = (1089.8711724325422, 10)
#  9 n_stockout:        536.0340 | n_holding:         61.8825 | stockout_cost:        536.0340 | holding_cost:        123.7651 | total_cost:        659.7991 | service_level:          0.3269
# 14 Out of control 1037.1527897439842 New (mu, sigma) = (1006.21063096879, 10)
# 15 Out of control 1014.5459970788874 New (mu, sigma) = (1014.5459970788874, 10)
# 22 Out of control 1028.2539978940706 New (mu, sigma) = (1030.1380255642732, 10)
# 27 Out of control 1067.1527897439842 New (mu, sigma) = (1047.435726743554, 10)
# 28 Out of control 1044.5459970788872 New (mu, sigma) = (1044.5459970788872, 10)
# 35 Out of control 1058.2539978940706 New (mu, sigma) = (1060.1380255642732, 10)
# 40 Out of control 1097.1527897439842 New (mu, sigma) = (1077.435726743554, 10)
# 41 Out of control 1074.5459970788872 New (mu, sigma) = (1074.5459970788872, 10)
# 48 Out of control 1088.2539978940706 New (mu, sigma) = (1090.1380255642732, 10)
# 10 n_stockout:        862.2270 | n_holding:         35.8279 | stockout_cost:        862.2270 | holding_cost:         71.6558 | total_cost:        933.8829 | service_level:          0.1154
# 14 Out of control 1027.139270031837 New (mu, sigma) = (1002.6152626626122, 10)
# 15 Out of control 1025.1543486777884 New (mu, sigma) = (1025.1543486777884, 10)
# 27 Out of control 1057.139270031837 New (mu, sigma) = (1032.453397818042, 10)
# 28 Out of control 1055.1543486777884 New (mu, sigma) = (1055.1543486777884, 10)
# 40 Out of control 1087.139270031837 New (mu, sigma) = (1062.453397818042, 10)
# 41 Out of control 1085.1543486777884 New (mu, sigma) = (1085.1543486777884, 10)
# 11 n_stockout:        601.4161 | n_holding:         91.8274 | stockout_cost:        601.4161 | holding_cost:        183.6547 | total_cost:        785.0708 | service_level:          0.2308
# 14 Out of control 1023.1857412056055 New (mu, sigma) = (1004.1757149180163, 10)
# 15 Out of control 1032.4243949669049 New (mu, sigma) = (1032.4243949669049, 10)
# 28 Out of control 1062.4243949669049 New (mu, sigma) = (1037.286163403826, 10)
# 29 Out of control 1042.9926436596168 New (mu, sigma) = (1042.9926436596168, 10)
# 36 Out of control 1054.0217708059365 New (mu, sigma) = (1060.814764998181, 10)
# 37 Out of control 1064.7245699353575 New (mu, sigma) = (1064.7245699353575, 10)
# 41 Out of control 1092.4243949669049 New (mu, sigma) = (1085.324888916874, 10)
# 49 Out of control 1084.0217708059365 New (mu, sigma) = (1088.5869998308608, 10)
# 12 n_stockout:        724.3864 | n_holding:         84.9414 | stockout_cost:        724.3864 | holding_cost:        169.8828 | total_cost:        894.2693 | service_level:          0.2115
# 15 Out of control 1029.5549692166194 New (mu, sigma) = (1007.7999730673957, 10)
# 16 Out of control 1034.518123387458 New (mu, sigma) = (1034.518123387458, 10)
# 28 Out of control 1059.5549692166194 New (mu, sigma) = (1040.026059942347, 10)
# 29 Out of control 1064.518123387458 New (mu, sigma) = (1064.518123387458, 10)
# 41 Out of control 1089.5549692166194 New (mu, sigma) = (1070.026059942347, 10)
# 42 Out of control 1094.518123387458 New (mu, sigma) = (1094.518123387458, 10)
# 13 n_stockout:        661.9828 | n_holding:        115.6314 | stockout_cost:        661.9828 | holding_cost:        231.2627 | total_cost:        893.2455 | service_level:          0.2500
# 14 Out of control 1030.7918602460882 New (mu, sigma) = (1003.6614041776864, 10)
# 15 Out of control 1031.7397652845616 New (mu, sigma) = (1031.7397652845616, 10)
# 27 Out of control 1060.7918602460882 New (mu, sigma) = (1033.0730038351765, 10)
# 28 Out of control 1061.7397652845616 New (mu, sigma) = (1061.7397652845616, 10)
# 40 Out of control 1090.7918602460882 New (mu, sigma) = (1063.0730038351765, 10)
# 41 Out of control 1091.7397652845616 New (mu, sigma) = (1091.7397652845616, 10)
# 14 n_stockout:        497.0137 | n_holding:        157.5317 | stockout_cost:        497.0137 | holding_cost:        315.0634 | total_cost:        812.0772 | service_level:          0.3077
# 15 Out of control 1028.4409146611729 New (mu, sigma) = (1002.8711519319064, 10)
# 16 Out of control 1024.9821032670225 New (mu, sigma) = (1024.9821032670225, 10)
# 28 Out of control 1058.4409146611729 New (mu, sigma) = (1034.3538208947734, 10)
# 29 Out of control 1054.9821032670225 New (mu, sigma) = (1054.9821032670225, 10)
# 41 Out of control 1088.4409146611729 New (mu, sigma) = (1064.3538208947734, 10)
# 42 Out of control 1084.9821032670225 New (mu, sigma) = (1084.9821032670225, 10)
# 15 n_stockout:        629.0836 | n_holding:         62.1818 | stockout_cost:        629.0836 | holding_cost:        124.3636 | total_cost:        753.4472 | service_level:          0.2692
# 16 Out of control 1030.6633037374593 New (mu, sigma) = (1002.4263057698079, 10)
# 17 Out of control 1017.6450512675935 New (mu, sigma) = (1017.6450512675935, 10)
# 27 Out of control 1044.7152654117413 New (mu, sigma) = (1031.8170146321236, 10)
# 28 Out of control 1054.0553201999537 New (mu, sigma) = (1054.0553201999537, 10)
# 40 Out of control 1074.7152654117413 New (mu, sigma) = (1060.539875110524, 10)
# 41 Out of control 1084.0553201999537 New (mu, sigma) = (1084.0553201999537, 10)
# 16 n_stockout:        607.9297 | n_holding:         42.2670 | stockout_cost:        607.9297 | holding_cost:         84.5340 | total_cost:        692.4637 | service_level:          0.1923
# 14 Out of control 1011.453719211935 New (mu, sigma) = (1005.518776396112, 10)
# 16 Out of control 1041.453112895721 New (mu, sigma) = (1038.8460620044923, 10)
# 17 Out of control 1040.371904682279 New (mu, sigma) = (1040.371904682279, 10)
# 30 Out of control 1070.371904682279 New (mu, sigma) = (1044.5050206022718, 10)
# 31 Out of control 1078.866389297816 New (mu, sigma) = (1078.866389297816, 10)
# 45 Out of control 1088.8830170987123 New (mu, sigma) = (1077.6748774948744, 10)
# 46 Out of control 1086.3789866160096 New (mu, sigma) = (1086.3789866160096, 10)
# 17 n_stockout:        684.6614 | n_holding:        199.3448 | stockout_cost:        684.6614 | holding_cost:        398.6896 | total_cost:       1083.3510 | service_level:          0.3077
# 15 Out of control 1028.6510785339174 New (mu, sigma) = (1010.445914986715, 10)
# 16 Out of control 1031.6051798245487 New (mu, sigma) = (1031.6051798245487, 10)
# 28 Out of control 1058.6510785339174 New (mu, sigma) = (1042.0151727847308, 10)
# 29 Out of control 1061.6051798245487 New (mu, sigma) = (1061.6051798245487, 10)
# 41 Out of control 1088.6510785339174 New (mu, sigma) = (1072.0151727847308, 10)
# 42 Out of control 1091.6051798245487 New (mu, sigma) = (1091.6051798245487, 10)
# 18 n_stockout:        735.0880 | n_holding:         15.4080 | stockout_cost:        735.0880 | holding_cost:         30.8161 | total_cost:        765.9041 | service_level:          0.1346
# 15 Out of control 1024.2225145801947 New (mu, sigma) = (1003.4227539328804, 10)
# 16 Out of control 1025.9596844494577 New (mu, sigma) = (1025.9596844494577, 10)
# 27 Out of control 1056.595349910216 New (mu, sigma) = (1033.7776333435636, 10)
# 28 Out of control 1054.2225145801947 New (mu, sigma) = (1054.2225145801947, 10)
# 40 Out of control 1086.595349910216 New (mu, sigma) = (1063.1261376023883, 10)
# 41 Out of control 1084.2225145801947 New (mu, sigma) = (1084.2225145801947, 10)
# 19 n_stockout:        630.1271 | n_holding:         57.9826 | stockout_cost:        630.1271 | holding_cost:        115.9651 | total_cost:        746.0922 | service_level:          0.1923
# 14 Out of control 1031.9586502203765 New (mu, sigma) = (1003.7047916904083, 10)
# 15 Out of control 1033.575365158853 New (mu, sigma) = (1033.575365158853, 10)
# 27 Out of control 1061.9586502203765 New (mu, sigma) = (1033.4332440708936, 10)
# 28 Out of control 1063.575365158853 New (mu, sigma) = (1063.575365158853, 10)
# 40 Out of control 1091.9586502203765 New (mu, sigma) = (1063.4332440708936, 10)
# 41 Out of control 1093.575365158853 New (mu, sigma) = (1093.575365158853, 10)
# 20 n_stockout:        496.1068 | n_holding:        195.1651 | stockout_cost:        496.1068 | holding_cost:        390.3303 | total_cost:        886.4371 | service_level:          0.3846
# 15 Out of control 1040.4179679908414 New (mu, sigma) = (1007.238393896056, 10)
# 16 Out of control 1017.4326070593502 New (mu, sigma) = (1017.4326070593502, 10)
# 26 Out of control 1059.4803575049448 New (mu, sigma) = (1035.0289322798008, 10)
# 27 Out of control 1058.8880394964558 New (mu, sigma) = (1058.8880394964558, 10)
# 40 Out of control 1088.8880394964558 New (mu, sigma) = (1065.9252259495888, 10)
# 41 Out of control 1100.4179679908414 New (mu, sigma) = (1100.4179679908414, 10)
# 42 Out of control 1077.4326070593502 New (mu, sigma) = (1077.4326070593502, 10)
# 21 n_stockout:        848.3056 | n_holding:         61.5902 | stockout_cost:        848.3056 | holding_cost:        123.1804 | total_cost:        971.4859 | service_level:          0.1731
# 16 Out of control 1027.6067483180243 New (mu, sigma) = (1005.4981999722738, 10)
# 17 Out of control 1025.0887086376158 New (mu, sigma) = (1025.0887086376158, 10)
# 27 Out of control 1045.3664934718831 New (mu, sigma) = (1033.7084366397794, 10)
# 29 Out of control 1057.6067483180243 New (mu, sigma) = (1064.2123325550037, 10)
# 30 Out of control 1055.0887086376158 New (mu, sigma) = (1055.0887086376158, 10)
# 40 Out of control 1075.3664934718831 New (mu, sigma) = (1063.7084366397794, 10)
# 42 Out of control 1087.6067483180243 New (mu, sigma) = (1094.2123325550037, 10)
# 43 Out of control 1085.0887086376158 New (mu, sigma) = (1085.0887086376158, 10)
# 22 n_stockout:        687.3098 | n_holding:         42.1811 | stockout_cost:        687.3098 | holding_cost:         84.3621 | total_cost:        771.6719 | service_level:          0.2500
# 14 Out of control 1030.2581308106628 New (mu, sigma) = (1004.5315083706548, 10)
# 15 Out of control 1022.2238058680819 New (mu, sigma) = (1022.2238058680819, 10)
# 27 Out of control 1060.2581308106628 New (mu, sigma) = (1035.7350673597955, 10)
# 28 Out of control 1052.2238058680819 New (mu, sigma) = (1052.2238058680819, 10)
# 40 Out of control 1090.2581308106628 New (mu, sigma) = (1065.7350673597955, 10)
# 41 Out of control 1082.2238058680819 New (mu, sigma) = (1082.2238058680819, 10)
# 23 n_stockout:        775.6136 | n_holding:         29.0680 | stockout_cost:        775.6136 | holding_cost:         58.1360 | total_cost:        833.7497 | service_level:          0.1346
# 14 Out of control 1022.2996654799515 New (mu, sigma) = (1004.1897685288462, 10)
# 15 Out of control 1026.8371964037858 New (mu, sigma) = (1026.8371964037858, 10)
# 27 Out of control 1052.2996654799515 New (mu, sigma) = (1035.0347953602052, 10)
# 28 Out of control 1056.8371964037858 New (mu, sigma) = (1056.8371964037858, 10)
# 40 Out of control 1082.2996654799515 New (mu, sigma) = (1065.0347953602052, 10)
# 41 Out of control 1086.8371964037858 New (mu, sigma) = (1086.8371964037858, 10)
# 24 n_stockout:        677.8659 | n_holding:        101.5928 | stockout_cost:        677.8659 | holding_cost:        203.1856 | total_cost:        881.0516 | service_level:          0.3269
# 14 Out of control 1040.26890303163 New (mu, sigma) = (1004.6223991919607, 10)
# 15 Out of control 1021.6041515103482 New (mu, sigma) = (1021.6041515103482, 10)
# 27 Out of control 1070.26890303163 New (mu, sigma) = (1035.4316835367308, 10)
# 28 Out of control 1051.6041515103482 New (mu, sigma) = (1051.6041515103482, 10)
# 40 Out of control 1100.26890303163 New (mu, sigma) = (1065.4316835367308, 10)
# 41 Out of control 1081.6041515103482 New (mu, sigma) = (1081.6041515103482, 10)
# 25 n_stockout:        808.5480 | n_holding:         57.4593 | stockout_cost:        808.5480 | holding_cost:        114.9185 | total_cost:        923.4665 | service_level:          0.1731
# 16 Out of control 1036.6214814852176 New (mu, sigma) = (1005.3795610514779, 10)
# 17 Out of control 1027.7113787895369 New (mu, sigma) = (1027.7113787895369, 10)
# 27 Out of control 1040.5876359972392 New (mu, sigma) = (1032.36749184128, 10)
# 29 Out of control 1066.6214814852176 New (mu, sigma) = (1066.8796681397366, 10)
# 30 Out of control 1057.7113787895369 New (mu, sigma) = (1057.7113787895369, 10)
# 40 Out of control 1070.5876359972392 New (mu, sigma) = (1062.36749184128, 10)
# 42 Out of control 1096.6214814852176 New (mu, sigma) = (1096.8796681397366, 10)
# 43 Out of control 1087.7113787895369 New (mu, sigma) = (1087.7113787895369, 10)
# 26 n_stockout:        657.3022 | n_holding:        107.2689 | stockout_cost:        657.3022 | holding_cost:        214.5378 | total_cost:        871.8400 | service_level:          0.2885
# 14 Out of control 1026.9644662269384 New (mu, sigma) = (1007.7499751989079, 10)
# 15 Out of control 1036.1907566186944 New (mu, sigma) = (1036.1907566186944, 10)
# 27 Out of control 1056.9644662269384 New (mu, sigma) = (1038.3531959154718, 10)
# 28 Out of control 1066.1907566186944 New (mu, sigma) = (1066.1907566186944, 10)
# 40 Out of control 1086.9644662269384 New (mu, sigma) = (1068.3531959154718, 10)
# 41 Out of control 1096.1907566186944 New (mu, sigma) = (1096.1907566186944, 10)
# 27 n_stockout:        486.8507 | n_holding:         42.0981 | stockout_cost:        486.8507 | holding_cost:         84.1962 | total_cost:        571.0469 | service_level:          0.1923
# 14 Out of control 1046.6912005100796 New (mu, sigma) = (1004.2454073853754, 10)
# 15 Out of control 1027.3572003817621 New (mu, sigma) = (1027.3572003817621, 10)
# 16 Out of control 1020.3216507062622 New (mu, sigma) = (1020.3216507062622, 10)
# 27 Out of control 1076.6912005100796 New (mu, sigma) = (1034.9861577639842, 10)
# 28 Out of control 1057.3572003817621 New (mu, sigma) = (1057.3572003817621, 10)
# 40 Out of control 1106.6912005100796 New (mu, sigma) = (1063.7641155091742, 10)
# 41 Out of control 1087.3572003817621 New (mu, sigma) = (1087.3572003817621, 10)
# 28 n_stockout:        669.1149 | n_holding:         90.7798 | stockout_cost:        669.1149 | holding_cost:        181.5597 | total_cost:        850.6746 | service_level:          0.2500
# 15 Out of control 1049.1598470252497 New (mu, sigma) = (1007.353399646712, 10)
# 16 Out of control 1008.5824450427 New (mu, sigma) = (1008.5824450427, 10)
# 18 Out of control 1034.6707261559782 New (mu, sigma) = (1035.9306475290134, 10)
# 28 Out of control 1079.1598470252497 New (mu, sigma) = (1040.5165307522934, 10)
# 29 Out of control 1038.5824450426999 New (mu, sigma) = (1038.5824450426999, 10)
# 31 Out of control 1064.6707261559782 New (mu, sigma) = (1065.9306475290134, 10)
# 41 Out of control 1109.1598470252497 New (mu, sigma) = (1070.5165307522934, 10)
# 42 Out of control 1068.5824450426999 New (mu, sigma) = (1068.5824450426999, 10)
# 44 Out of control 1094.6707261559782 New (mu, sigma) = (1095.9306475290134, 10)
# 29 n_stockout:        694.6038 | n_holding:        148.1980 | stockout_cost:        694.6038 | holding_cost:        296.3961 | total_cost:        990.9999 | service_level:          0.3077
# 15 Out of control 1020.2928906199114 New (mu, sigma) = (1005.0426183213906, 10)
# 16 Out of control 1034.7055961588642 New (mu, sigma) = (1034.7055961588642, 10)
# 28 Out of control 1050.2928906199113 New (mu, sigma) = (1036.9204066245711, 10)
# 29 Out of control 1064.7055961588642 New (mu, sigma) = (1064.7055961588642, 10)
# 41 Out of control 1080.2928906199113 New (mu, sigma) = (1066.9204066245711, 10)
# 42 Out of control 1094.7055961588642 New (mu, sigma) = (1094.7055961588642, 10)
# 30 n_stockout:        553.2987 | n_holding:        152.4867 | stockout_cost:        553.2987 | holding_cost:        304.9734 | total_cost:        858.2720 | service_level:          0.3269
# 15 Out of control 1030.8109198556483 New (mu, sigma) = (1003.3421908118969, 10)
# 16 Out of control 1022.0897304757567 New (mu, sigma) = (1022.0897304757567, 10)
# 27 Out of control 1056.666313313325 New (mu, sigma) = (1033.3858856029533, 10)
# 28 Out of control 1060.8109198556483 New (mu, sigma) = (1060.8109198556483, 10)
# 29 Out of control 1052.0897304757568 New (mu, sigma) = (1052.0897304757568, 10)
# 40 Out of control 1086.666313313325 New (mu, sigma) = (1063.3858856029533, 10)
# 41 Out of control 1090.8109198556483 New (mu, sigma) = (1090.8109198556483, 10)
# 42 Out of control 1082.0897304757568 New (mu, sigma) = (1082.0897304757568, 10)
# 31 n_stockout:        665.5307 | n_holding:         27.4884 | stockout_cost:        665.5307 | holding_cost:         54.9767 | total_cost:        720.5074 | service_level:          0.1346
# 14 Out of control 1039.837034333518 New (mu, sigma) = (1009.6775664313619, 10)
# 15 Out of control 1035.8092283071715 New (mu, sigma) = (1035.8092283071715, 10)
# 16 Out of control 1030.7028444085745 New (mu, sigma) = (1030.7028444085745, 10)
# 28 Out of control 1065.8092283071715 New (mu, sigma) = (1044.0093801865191, 10)
# 29 Out of control 1060.7028444085745 New (mu, sigma) = (1060.7028444085745, 10)
# 41 Out of control 1095.8092283071715 New (mu, sigma) = (1074.0093801865191, 10)
# 42 Out of control 1090.7028444085745 New (mu, sigma) = (1090.7028444085745, 10)
# 32 n_stockout:        828.4424 | n_holding:         25.9020 | stockout_cost:        828.4424 | holding_cost:         51.8040 | total_cost:        880.2464 | service_level:          0.1731
# 17 Out of control 1027.8327169880413 New (mu, sigma) = (1004.4853173463845, 10)
# 18 Out of control 1032.5487430067676 New (mu, sigma) = (1032.5487430067676, 10)
# 31 Out of control 1062.5487430067676 New (mu, sigma) = (1041.7828864240644, 10)
# 32 Out of control 1058.5055006292812 New (mu, sigma) = (1058.5055006292812, 10)
# 43 Out of control 1087.8327169880413 New (mu, sigma) = (1071.1021163524354, 10)
# 44 Out of control 1092.5487430067676 New (mu, sigma) = (1092.5487430067676, 10)
# 33 n_stockout:        661.8306 | n_holding:         37.0480 | stockout_cost:        661.8306 | holding_cost:         74.0959 | total_cost:        735.9265 | service_level:          0.1731
# 14 Out of control 1022.526818184611 New (mu, sigma) = (1002.0454927466567, 10)
# 15 Out of control 1014.3882300541512 New (mu, sigma) = (1014.3882300541512, 10)
# 16 Out of control 1025.3574687821053 New (mu, sigma) = (1025.3574687821053, 10)
# 27 Out of control 1052.5268181846109 New (mu, sigma) = (1035.0883202884277, 10)
# 28 Out of control 1044.3882300541513 New (mu, sigma) = (1044.3882300541513, 10)
# 35 Out of control 1064.5081813325248 New (mu, sigma) = (1060.1432325109083, 10)
# 41 Out of control 1074.3882300541513 New (mu, sigma) = (1070.7857657387674, 10)
# 42 Out of control 1085.3574687821053 New (mu, sigma) = (1085.3574687821053, 10)
# 34 n_stockout:        664.2403 | n_holding:         38.4274 | stockout_cost:        664.2403 | holding_cost:         76.8548 | total_cost:        741.0951 | service_level:          0.1923
# 16 Out of control 1020.758733333445 New (mu, sigma) = (1002.2533936785003, 10)
# 17 Out of control 1015.7840216523244 New (mu, sigma) = (1015.7840216523244, 10)
# 18 Out of control 1038.0525598815811 New (mu, sigma) = (1038.0525598815811, 10)
# 33 Out of control 1071.6942839731958 New (mu, sigma) = (1044.7616939855502, 10)
# 34 Out of control 1051.9799071643463 New (mu, sigma) = (1051.9799071643463, 10)
# 41 Out of control 1082.3397399171222 New (mu, sigma) = (1066.9263406550556, 10)
# 42 Out of control 1080.758733333445 New (mu, sigma) = (1080.758733333445, 10)
# 35 n_stockout:        693.9227 | n_holding:         88.1763 | stockout_cost:        693.9227 | holding_cost:        176.3526 | total_cost:        870.2753 | service_level:          0.2308
# 14 Out of control 1045.2109918593392 New (mu, sigma) = (1003.1980347020923, 10)
# 15 Out of control 1024.88123754951 New (mu, sigma) = (1024.88123754951, 10)
# 27 Out of control 1075.2109918593392 New (mu, sigma) = (1032.5928465387494, 10)
# 28 Out of control 1054.88123754951 New (mu, sigma) = (1054.88123754951, 10)
# 40 Out of control 1105.2109918593392 New (mu, sigma) = (1062.5928465387494, 10)
# 41 Out of control 1084.88123754951 New (mu, sigma) = (1084.88123754951, 10)
# 36 n_stockout:        604.1460 | n_holding:         80.5321 | stockout_cost:        604.1460 | holding_cost:        161.0641 | total_cost:        765.2102 | service_level:          0.3077
# 15 Out of control 1033.4664702595844 New (mu, sigma) = (1008.9919294425683, 10)
# 16 Out of control 1016.9965382904599 New (mu, sigma) = (1016.9965382904599, 10)
# 18 Out of control 1039.8982370553501 New (mu, sigma) = (1042.5416779220488, 10)
# 31 Out of control 1069.8982370553501 New (mu, sigma) = (1047.246612021642, 10)
# 32 Out of control 1062.7768089713634 New (mu, sigma) = (1062.7768089713634, 10)
# 41 Out of control 1093.4664702595844 New (mu, sigma) = (1073.261028130603, 10)
# 42 Out of control 1076.99653829046 New (mu, sigma) = (1076.99653829046, 10)
# 44 Out of control 1099.8982370553501 New (mu, sigma) = (1102.5416779220488, 10)
# 37 n_stockout:        691.2643 | n_holding:        103.7729 | stockout_cost:        691.2643 | holding_cost:        207.5458 | total_cost:        898.8101 | service_level:          0.2885
# 14 Out of control 1026.7687664792418 New (mu, sigma) = (1004.9862803063945, 10)
# 15 Out of control 1031.2774641529118 New (mu, sigma) = (1031.2774641529118, 10)
# 27 Out of control 1056.7687664792418 New (mu, sigma) = (1035.555076456883, 10)
# 28 Out of control 1061.2774641529118 New (mu, sigma) = (1061.2774641529118, 10)
# 40 Out of control 1086.7687664792418 New (mu, sigma) = (1065.555076456883, 10)
# 41 Out of control 1091.2774641529118 New (mu, sigma) = (1091.2774641529118, 10)
# 38 n_stockout:        568.9027 | n_holding:        102.7011 | stockout_cost:        568.9027 | holding_cost:        205.4023 | total_cost:        774.3050 | service_level:          0.3077
# 14 Out of control 1032.2112104123996 New (mu, sigma) = (1005.3499812995726, 10)
# 15 Out of control 1028.546726934694 New (mu, sigma) = (1028.546726934694, 10)
# 27 Out of control 1062.2112104123996 New (mu, sigma) = (1035.453615540523, 10)
# 28 Out of control 1058.546726934694 New (mu, sigma) = (1058.546726934694, 10)
# 40 Out of control 1092.2112104123996 New (mu, sigma) = (1065.453615540523, 10)
# 41 Out of control 1088.546726934694 New (mu, sigma) = (1088.546726934694, 10)
# 39 n_stockout:        706.1958 | n_holding:        163.1031 | stockout_cost:        706.1958 | holding_cost:        326.2062 | total_cost:       1032.4020 | service_level:          0.2308
# 15 Out of control 1023.1539364129536 New (mu, sigma) = (1006.3925877170277, 10)
# 16 Out of control 1039.2871474859346 New (mu, sigma) = (1039.2871474859346, 10)
# 30 Out of control 1041.5559896594973 New (mu, sigma) = (1041.287164131226, 10)
# 33 Out of control 1064.8881005439557 New (mu, sigma) = (1067.7143265782336, 10)
# 34 Out of control 1067.1026699066067 New (mu, sigma) = (1067.1026699066067, 10)
# 43 Out of control 1071.5559896594973 New (mu, sigma) = (1076.246517615151, 10)
# 44 Out of control 1085.329975759229 New (mu, sigma) = (1085.329975759229, 10)
# 40 n_stockout:        705.6486 | n_holding:         61.2821 | stockout_cost:        705.6486 | holding_cost:        122.5641 | total_cost:        828.2127 | service_level:          0.2115
# 15 Out of control 1032.5052781572358 New (mu, sigma) = (1002.4472548289868, 10)
# 16 Out of control 1020.7480003472192 New (mu, sigma) = (1020.7480003472192, 10)
# 27 Out of control 1061.0484805260974 New (mu, sigma) = (1031.3687421187888, 10)
# 28 Out of control 1062.5052781572358 New (mu, sigma) = (1062.5052781572358, 10)
# 41 Out of control 1092.5052781572358 New (mu, sigma) = (1062.9468801393177, 10)
# 42 Out of control 1080.7480003472192 New (mu, sigma) = (1080.7480003472192, 10)
# 41 n_stockout:        579.3004 | n_holding:         86.3759 | stockout_cost:        579.3004 | holding_cost:        172.7518 | total_cost:        752.0522 | service_level:          0.2692
# 14 Out of control 1028.617356988288 New (mu, sigma) = (1006.7679171960074, 10)
# 15 Out of control 1036.476885381007 New (mu, sigma) = (1036.476885381007, 10)
# 28 Out of control 1066.476885381007 New (mu, sigma) = (1039.841096878593, 10)
# 29 Out of control 1075.2302985640802 New (mu, sigma) = (1075.2302985640802, 10)
# 43 Out of control 1087.6584662527666 New (mu, sigma) = (1073.2566232624627, 10)
# 44 Out of control 1087.658630430508 New (mu, sigma) = (1087.658630430508, 10)
# 42 n_stockout:        575.9308 | n_holding:        121.1153 | stockout_cost:        575.9308 | holding_cost:        242.2307 | total_cost:        818.1615 | service_level:          0.3077
# 14 Out of control 1020.9151856721934 New (mu, sigma) = (1004.0011568155431, 10)
# 15 Out of control 1026.2149689394118 New (mu, sigma) = (1026.2149689394118, 10)
# 27 Out of control 1050.9151856721935 New (mu, sigma) = (1035.8594331973413, 10)
# 28 Out of control 1056.2149689394118 New (mu, sigma) = (1056.2149689394118, 10)
# 40 Out of control 1080.9151856721935 New (mu, sigma) = (1065.8594331973413, 10)
# 41 Out of control 1086.2149689394118 New (mu, sigma) = (1086.2149689394118, 10)
# 43 n_stockout:        677.1285 | n_holding:         44.0666 | stockout_cost:        677.1285 | holding_cost:         88.1332 | total_cost:        765.2618 | service_level:          0.1346
# 15 Out of control 1042.4614002864344 New (mu, sigma) = (1004.9737638664099, 10)
# 16 Out of control 1013.9508425874141 New (mu, sigma) = (1013.9508425874141, 10)
# 20 Out of control 1030.875879762658 New (mu, sigma) = (1026.9078938270627, 10)
# 21 Out of control 1029.4767780357527 New (mu, sigma) = (1029.4767780357527, 10)
# 28 Out of control 1072.4614002864344 New (mu, sigma) = (1042.9145999385926, 10)
# 29 Out of control 1043.950842587414 New (mu, sigma) = (1043.950842587414, 10)
# 33 Out of control 1060.875879762658 New (mu, sigma) = (1056.9078938270627, 10)
# 34 Out of control 1059.4767780357527 New (mu, sigma) = (1059.4767780357527, 10)
# 41 Out of control 1102.4614002864344 New (mu, sigma) = (1072.9145999385926, 10)
# 42 Out of control 1073.950842587414 New (mu, sigma) = (1073.950842587414, 10)
# 46 Out of control 1090.875879762658 New (mu, sigma) = (1086.9078938270627, 10)
# 47 Out of control 1089.4767780357527 New (mu, sigma) = (1089.4767780357527, 10)
# 44 n_stockout:        736.7384 | n_holding:         86.4334 | stockout_cost:        736.7384 | holding_cost:        172.8667 | total_cost:        909.6051 | service_level:          0.2308
# 15 Out of control 1026.0485445848221 New (mu, sigma) = (1002.6415257259911, 10)
# 16 Out of control 1027.9569909496174 New (mu, sigma) = (1027.9569909496174, 10)
# 28 Out of control 1056.0485445848221 New (mu, sigma) = (1033.7826592782246, 10)
# 29 Out of control 1057.9569909496174 New (mu, sigma) = (1057.9569909496174, 10)
# 41 Out of control 1086.0485445848221 New (mu, sigma) = (1063.7826592782246, 10)
# 42 Out of control 1087.9569909496174 New (mu, sigma) = (1087.9569909496174, 10)
# 45 n_stockout:        609.7590 | n_holding:        155.1727 | stockout_cost:        609.7590 | holding_cost:        310.3455 | total_cost:        920.1045 | service_level:          0.3077
# 14 Out of control 1042.3119574044056 New (mu, sigma) = (1007.1567187115685, 10)
# 15 Out of control 1038.219002640012 New (mu, sigma) = (1038.219002640012, 10)
# 28 Out of control 1068.219002640012 New (mu, sigma) = (1039.1684665284936, 10)
# 29 Out of control 1052.0077164280356 New (mu, sigma) = (1052.0077164280356, 10)
# 40 Out of control 1102.3119574044056 New (mu, sigma) = (1068.0875768911249, 10)
# 41 Out of control 1098.219002640012 New (mu, sigma) = (1098.219002640012, 10)
# 46 n_stockout:        630.3859 | n_holding:        115.1822 | stockout_cost:        630.3859 | holding_cost:        230.3644 | total_cost:        860.7503 | service_level:          0.3269
# 15 Out of control 1039.2420796621802 New (mu, sigma) = (1006.7809207539684, 10)
# 16 Out of control 1036.4041180123309 New (mu, sigma) = (1036.4041180123309, 10)
# 28 Out of control 1069.2420796621802 New (mu, sigma) = (1037.3557971305966, 10)
# 29 Out of control 1066.4041180123309 New (mu, sigma) = (1066.4041180123309, 10)
# 41 Out of control 1099.2420796621802 New (mu, sigma) = (1067.3557971305966, 10)
# 42 Out of control 1096.4041180123309 New (mu, sigma) = (1096.4041180123309, 10)
# 47 n_stockout:        598.5062 | n_holding:        228.6616 | stockout_cost:        598.5062 | holding_cost:        457.3233 | total_cost:       1055.8295 | service_level:          0.4615
# 16 Out of control 1040.6158868899097 New (mu, sigma) = (1006.0807756989568, 10)
# 17 Out of control 1028.425958486134 New (mu, sigma) = (1028.425958486134, 10)
# 18 Out of control 1040.9372847868412 New (mu, sigma) = (1040.9372847868412, 10)
# 32 Out of control 1039.2514598145447 New (mu, sigma) = (1043.4971314441884, 10)
# 33 Out of control 1067.0063300880981 New (mu, sigma) = (1067.0063300880981, 10)
# 43 Out of control 1088.425958486134 New (mu, sigma) = (1075.2513305714608, 10)
# 44 Out of control 1100.9372847868412 New (mu, sigma) = (1100.9372847868412, 10)
# 48 n_stockout:        658.5745 | n_holding:        198.7642 | stockout_cost:        658.5745 | holding_cost:        397.5285 | total_cost:       1056.1030 | service_level:          0.3269
# 16 Out of control 1048.2262686298934 New (mu, sigma) = (1008.8608067666642, 10)
# 17 Out of control 1015.5841658973798 New (mu, sigma) = (1015.5841658973798, 10)
# 23 Out of control 1043.6784398623367 New (mu, sigma) = (1036.6106783837554, 10)
# 24 Out of control 1027.3863783536274 New (mu, sigma) = (1027.3863783536274, 10)
# 29 Out of control 1078.2262686298934 New (mu, sigma) = (1054.3523041997885, 10)
# 30 Out of control 1045.5841658973798 New (mu, sigma) = (1045.5841658973798, 10)
# 36 Out of control 1073.6784398623367 New (mu, sigma) = (1066.6106783837554, 10)
# 37 Out of control 1057.3863783536274 New (mu, sigma) = (1057.3863783536274, 10)
# 42 Out of control 1108.2262686298934 New (mu, sigma) = (1084.3523041997885, 10)
# 43 Out of control 1075.5841658973798 New (mu, sigma) = (1075.5841658973798, 10)
# 49 Out of control 1103.6784398623367 New (mu, sigma) = (1096.6106783837554, 10)
# 50 Out of control 1087.3863783536274 New (mu, sigma) = (1087.3863783536274, 10)
# 49 n_stockout:       1026.3759 | n_holding:         43.9758 | stockout_cost:       1026.3759 | holding_cost:         87.9515 | total_cost:       1114.3274 | service_level:          0.1731
# 16 Out of control 1015.3541951479839 New (mu, sigma) = (1002.9099012230081, 10)
# 17 Out of control 1044.1194612178688 New (mu, sigma) = (1044.1194612178688, 10)
# 39 Out of control 1074.3964789131635 New (mu, sigma) = (1047.7054008143068, 10)
# 40 Out of control 1089.690223965263 New (mu, sigma) = (1089.690223965263, 10)
# 41 Out of control 1083.7907157611953 New (mu, sigma) = (1083.7907157611953, 10)
# 50 n_stockout:        626.3501 | n_holding:        146.2659 | stockout_cost:        626.3501 | holding_cost:        292.5317 | total_cost:        918.8818 | service_level:          0.3462
# 15 Out of control 1042.5079512280408 New (mu, sigma) = (1005.1658911899865, 10)
# 16 Out of control 1016.3911002887786 New (mu, sigma) = (1016.3911002887786, 10)
# 23 Out of control 1024.9434920885249 New (mu, sigma) = (1030.4841206656045, 10)
# 24 Out of control 1024.156907919159 New (mu, sigma) = (1024.156907919159, 10)
# 27 Out of control 1061.1212804706227 New (mu, sigma) = (1045.1617516597987, 10)
# 28 Out of control 1072.5079512280408 New (mu, sigma) = (1072.5079512280408, 10)
# 42 Out of control 1076.3911002887785 New (mu, sigma) = (1066.3086542402418, 10)
# 44 Out of control 1089.5200889691127 New (mu, sigma) = (1090.2597088960993, 10)
# 45 Out of control 1086.4377030974624 New (mu, sigma) = (1086.4377030974624, 10)
# 51 n_stockout:        634.6147 | n_holding:        167.5510 | stockout_cost:        634.6147 | holding_cost:        335.1020 | total_cost:        969.7166 | service_level:          0.3462
# 14 Out of control 1017.312496192451 New (mu, sigma) = (1005.7087266229977, 10)
# 15 Out of control 1032.4042002619622 New (mu, sigma) = (1032.4042002619622, 10)
# 27 Out of control 1047.312496192451 New (mu, sigma) = (1037.5599537070343, 10)
# 29 Out of control 1051.96042568202 New (mu, sigma) = (1057.182312971991, 10)
# 30 Out of control 1060.1734409962692 New (mu, sigma) = (1060.1734409962692, 10)
# 40 Out of control 1077.312496192451 New (mu, sigma) = (1069.858557780612, 10)
# 41 Out of control 1092.4042002619622 New (mu, sigma) = (1092.4042002619622, 10)
# 52 n_stockout:        608.9578 | n_holding:         34.9813 | stockout_cost:        608.9578 | holding_cost:         69.9627 | total_cost:        678.9205 | service_level:          0.2115
# 15 Out of control 1009.2736022142565 New (mu, sigma) = (1004.3608179080645, 10)
# 16 Out of control 1023.6731282692367 New (mu, sigma) = (1023.6731282692367, 10)
# 19 Out of control 1024.5876632732518 New (mu, sigma) = (1039.5014885721328, 10)
# 20 Out of control 1037.5270542050328 New (mu, sigma) = (1037.5270542050328, 10)
# 28 Out of control 1039.2736022142565 New (mu, sigma) = (1035.8835712954776, 10)
# 29 Out of control 1053.6731282692367 New (mu, sigma) = (1053.6731282692367, 10)
# 32 Out of control 1054.5876632732518 New (mu, sigma) = (1069.5014885721328, 10)
# 33 Out of control 1067.5270542050328 New (mu, sigma) = (1067.5270542050328, 10)
# 41 Out of control 1069.2736022142565 New (mu, sigma) = (1065.8835712954779, 10)
# 42 Out of control 1083.6731282692367 New (mu, sigma) = (1083.6731282692367, 10)
# 45 Out of control 1084.5876632732518 New (mu, sigma) = (1099.5014885721328, 10)
# 46 Out of control 1097.5270542050328 New (mu, sigma) = (1097.5270542050328, 10)
# 53 n_stockout:        579.9560 | n_holding:        194.6437 | stockout_cost:        579.9560 | holding_cost:        389.2874 | total_cost:        969.2434 | service_level:          0.3846
# 16 Out of control 1016.458644087294 New (mu, sigma) = (1000.8278773635329, 10)
# 17 Out of control 1036.2614846015617 New (mu, sigma) = (1036.2614846015617, 10)
# 31 Out of control 1067.3338755180057 New (mu, sigma) = (1038.821114694094, 10)
# 32 Out of control 1045.2902144443083 New (mu, sigma) = (1045.2902144443083, 10)
# 41 Out of control 1090.7856382551083 New (mu, sigma) = (1064.5352790609045, 10)
# 42 Out of control 1076.458644087294 New (mu, sigma) = (1076.458644087294, 10)
# 54 n_stockout:        721.2925 | n_holding:        120.2522 | stockout_cost:        721.2925 | holding_cost:        240.5044 | total_cost:        961.7969 | service_level:          0.2308
# 17 Out of control 1032.5995267792061 New (mu, sigma) = (1006.4462091754724, 10)
# 18 Out of control 1026.1891361707992 New (mu, sigma) = (1026.1891361707992, 10)
# 28 Out of control 1041.9020890170545 New (mu, sigma) = (1038.474356007525, 10)
# 29 Out of control 1062.6265384030166 New (mu, sigma) = (1062.6265384030166, 10)
# 43 Out of control 1092.5995267792061 New (mu, sigma) = (1070.6255920148199, 10)
# 44 Out of control 1086.1891361707992 New (mu, sigma) = (1086.1891361707992, 10)
# 55 n_stockout:        746.1974 | n_holding:         55.1172 | stockout_cost:        746.1974 | holding_cost:        110.2343 | total_cost:        856.4317 | service_level:          0.1538
# 15 Out of control 1041.0268062216849 New (mu, sigma) = (1006.2362992675637, 10)
# 16 Out of control 1024.8782226882443 New (mu, sigma) = (1024.8782226882443, 10)
# 28 Out of control 1071.0268062216849 New (mu, sigma) = (1038.1929674628786, 10)
# 29 Out of control 1054.8782226882443 New (mu, sigma) = (1054.8782226882443, 10)
# 41 Out of control 1101.0268062216849 New (mu, sigma) = (1068.1929674628786, 10)
# 42 Out of control 1084.8782226882443 New (mu, sigma) = (1084.8782226882443, 10)
# 56 n_stockout:        784.3904 | n_holding:         41.2405 | stockout_cost:        784.3904 | holding_cost:         82.4809 | total_cost:        866.8713 | service_level:          0.1538
# 15 Out of control 1013.0987711005467 New (mu, sigma) = (1002.1778118486384, 10)
# 16 Out of control 1022.0558152358949 New (mu, sigma) = (1022.0558152358949, 10)
# 19 Out of control 1003.8848805081918 New (mu, sigma) = (1033.842983734559, 10)
# 20 Out of control 1037.660093907233 New (mu, sigma) = (1037.660093907233, 10)
# 31 Out of control 1082.364054064307 New (mu, sigma) = (1044.865293332853, 10)
# 32 Out of control 1033.8848805081918 New (mu, sigma) = (1033.8848805081918, 10)
# 34 Out of control 1077.4616800793851 New (mu, sigma) = (1072.560886993309, 10)
# 35 Out of control 1043.1086074945 New (mu, sigma) = (1043.1086074945, 10)
# 40 Out of control 1087.9935389743248 New (mu, sigma) = (1066.029856411115, 10)
# 41 Out of control 1073.0987711005466 New (mu, sigma) = (1073.0987711005466, 10)
# 45 Out of control 1063.8848805081918 New (mu, sigma) = (1090.8961916098929, 10)
# 46 Out of control 1097.660093907233 New (mu, sigma) = (1097.660093907233, 10)
# 57 n_stockout:        799.5625 | n_holding:        230.1414 | stockout_cost:        799.5625 | holding_cost:        460.2828 | total_cost:       1259.8453 | service_level:          0.3462
# 17 Out of control 1012.956392333859 New (mu, sigma) = (1000.7459430285083, 10)
# 18 Out of control 1035.8140397605373 New (mu, sigma) = (1035.8140397605373, 10)
# 36 Out of control 1061.7241294280643 New (mu, sigma) = (1042.8845511947395, 10)
# 37 Out of control 1047.7284362276182 New (mu, sigma) = (1047.7284362276182, 10)
# 40 Out of control 1068.9841598915395 New (mu, sigma) = (1068.0913319948993, 10)
# 41 Out of control 1081.9024331542312 New (mu, sigma) = (1081.9024331542312, 10)
# 58 n_stockout:        642.2358 | n_holding:        127.7977 | stockout_cost:        642.2358 | holding_cost:        255.5954 | total_cost:        897.8311 | service_level:          0.3077
# 15 Out of control 1034.2038343210102 New (mu, sigma) = (1001.0854197909481, 10)
# 16 Out of control 1013.9864088958465 New (mu, sigma) = (1013.9864088958465, 10)
# 21 Out of control 1018.776781743605 New (mu, sigma) = (1027.710402530049, 10)
# 28 Out of control 1064.2038343210102 New (mu, sigma) = (1037.3835887221173, 10)
# 29 Out of control 1043.9864088958464 New (mu, sigma) = (1043.9864088958464, 10)
# 34 Out of control 1048.7767817436052 New (mu, sigma) = (1057.710402530049, 10)
# 41 Out of control 1094.2038343210102 New (mu, sigma) = (1067.3835887221176, 10)
# 42 Out of control 1073.9864088958464 New (mu, sigma) = (1073.9864088958464, 10)
# 47 Out of control 1078.7767817436052 New (mu, sigma) = (1087.710402530049, 10)
# 59 n_stockout:        697.6071 | n_holding:        111.1707 | stockout_cost:        697.6071 | holding_cost:        222.3415 | total_cost:        919.9486 | service_level:          0.1923
# ----------------------------------------------------------------------
#      n_stockout - mean:        661.7868, std:        102.9407
#       n_holding - mean:        108.0514, std:         64.1464
#   stockout_cost - mean:        661.7868, std:        102.9407
#    holding_cost - mean:        216.1028, std:        128.2928
#      total_cost - mean:        877.8897, std:        133.0317
#   service_level - mean:          0.2628, std:          0.0797
